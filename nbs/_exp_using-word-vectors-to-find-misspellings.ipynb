# %% [markdown]
# # Using Word Vectors to find misspellings

# %% [markdown]
# This notebook explores some of the ideas found [here](http://forums.fast.ai/t/nlp-any-libraries-dictionaries-out-there-for-fixing-common-spelling-errors/16411).
#
# Most notably the idea that we can use the vectors of misspelled word to create a single *transformation vector* that in turn, can be used to identify other misspelled words

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *

import html, pdb
import dill as pickle
from collections import Counter, defaultdict
import multiprocessing as mp

import spacy
spacy_en = spacy.load('en')
spacy_es = spacy.load('es')

# pandas and plotting config
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Configuration

# %%
# various default, LM, and classification paths
PATH = Path('data/verbatims')

LM_PATH = PATH/'lm'
CLS_PATH = PATH/'class'

(LM_PATH/'models').mkdir(parents=True, exist_ok=True)
(LM_PATH/'tmp').mkdir(exist_ok=True)

(CLS_PATH/'models').mkdir(parents=True, exist_ok=True)
(CLS_PATH/'tmp').mkdir(exist_ok=True)

# dataframe config
verbatims_filename = 'verbatims.csv'
date_cols = ['LastReviewedOn', 'LastPredictionsOn']
dtypes = { 'AnswerText': str, 'AnswerText_Cleaned': str, 'AnswerText_NonEnglish': str, 
          'p_Summary': str, 'LastReviewedBy' : str }

# columns for text, labels, and classes
TXT_COLS = ['AnswerText_Cleaned']

LABELS_SENT = ['IsVeryPositive', 'IsPositive', 'IsVeryNegative', 'IsNegative', 
             'IsSuggestion', 'FeelsThreatened', 'IsNonsense']

LABELS_ENT = ['HasPersonsName', 'HasOrgName', 'HasContactInfo']

LABELS = LABELS_SENT + LABELS_ENT
CLASSES = ['no', 'yes']

# %%
PRE_PATH = PATH/'models'/'wt103'
PRE_LM_PATH = PRE_PATH/'fwd_wt103.h5'

# %% [markdown]
# ## Wiki103 Embeddings with sklearn's NearestNeighbors

# %%
wgts = torch.load(PRE_LM_PATH, map_location=lambda storage, loc: storage)

# %%
list(wgts.keys()), wgts['0.encoder.weight'].size()
# Out:
# (['0.encoder.weight',
#   '0.encoder_with_dropout.embed.weight',
#   '0.rnns.0.module.weight_ih_l0',
#   '0.rnns.0.module.bias_ih_l0',
#   '0.rnns.0.module.bias_hh_l0',
#   '0.rnns.0.module.weight_hh_l0_raw',
#   '0.rnns.1.module.weight_ih_l0',
#   '0.rnns.1.module.bias_ih_l0',
#   '0.rnns.1.module.bias_hh_l0',
#   '0.rnns.1.module.weight_hh_l0_raw',
#   '0.rnns.2.module.weight_ih_l0',
#   '0.rnns.2.module.bias_ih_l0',
#   '0.rnns.2.module.bias_hh_l0',
#   '0.rnns.2.module.weight_hh_l0_raw',
#   '1.decoder.weight'],
#  torch.Size([238462, 400]))

# %%
enc_wgts = to_np(wgts['0.encoder.weight'])
row_m = enc_wgts.mean(0)

# %%
itos2 = pickle.load((PRE_PATH/'itos_wt103.pkl').open('rb'))
stoi2 = collections.defaultdict(lambda: -1, { v:k for k,v in enumerate(itos2) })

# %% [markdown]
# #### Convert embedding matrix to np

# %%
emb = to_np(wgts['0.encoder.weight'])

# %%
emb.shape, len(itos2)
# Out:
# ((238462, 400), 238462)

# %%
itos2[100]  # "world"
# Out:
# 'world'

# %%
emb[100].shape # 400D vector for word "world"
# Out:
# (400,)

# %% [markdown]
# #### Use KNN to evaluate vector space

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nbrs = NearestNeighbors(n_neighbors=8, metric="cosine").fit(emb)

# %% [markdown]
# How to find the first 5 words that start with "god" (`select * from words where word like 'god%'`)

# %%
sorted([s for s in itos2 if (s.startswith('god'))])[:5]
# Out:
# ['god', 'goda', 'godaddy', 'godai', 'godal']

# %% [markdown]
# How to find the index of the word "god" (use `list.index(val)`)

# %%
itos2.index('god')
# Out:
# 921

# %% [markdown]
# Look up the vector and add a dimension for nn

# %%
word_vec = np.expand_dims(emb[921], 0) # (400,) => (1,400)
word_vec.shape
# Out:
# (1, 400)

# %%
dist, near_idxs = nbrs.kneighbors(word_vec)

print(dist)
print(near_idxs)
# Out:
# [[0.      0.32039 0.34489 0.34614 0.34909 0.35    0.35193 0.35347]]
# [[  921  5085 14224  3431  8117  4365 12068  3260]]

# %% [markdown]
# Look up the words based on the indexes of the word's nearest neighbors

# %%
[itos2[idx] for idx in near_idxs.squeeze()]
# Out:
# ['god', 'goddess', 'satan', 'christ', 'deity', 'gods', 'mankind', 'jesus']

# %% [markdown]
# Some fun.  What does "god" - "satan" mean?  Or "god" + "satan"?

# %%
vec_diff = emb[itos2.index('god')] - emb[itos2.index('satan')] 
dist, near_idxs = nbrs.kneighbors(np.expand_dims(vec_diff,0))
[itos2[idx] for idx in near_idxs.squeeze()]
# Out:
# ['god', 'goddess', 'christ', 'divine', 'deity', 'you', 'gods', 'someone']

# %%
vec_add = emb[itos2.index('god')] + emb[itos2.index('satan')] 
dist, near_idxs = nbrs.kneighbors(np.expand_dims(vec_add,0))
[itos2[idx] for idx in near_idxs.squeeze()]
# Out:
# ['god', 'satan', 'humankind', 'allah', 'athena', 'babylon', 'lucifer', 'cupid']

# %% [markdown]
# Using sklearn's `cosine_similarity` to basically do the same thing KNN does above, except it is going to pull up the results for the entire vocab.
#
# We can then use `np.argsort()` to find the closest and furthest neighbors

# %%
from sklearn.metrics.pairwise import cosine_similarity
cos_sim = cosine_similarity(emb[np.expand_dims(itos2.index('god'), 0)], emb)

print(cos_sim.shape)
# Out:
# (1, 238462)

# %%
cos_sim[0,:5]
np.argsort(cos_sim[0])[:5]        # => sort desc; get first 5 (farthest away)
np.argsort(cos_sim[0])[::-1][:5]  # => sort asc; get first 5 (closest)
# Out:
# array([  921,  5085, 14224,  3431,  8117])

# %%
[itos2[idx] for idx in np.argsort(cos_sim[0])[::-1][:5]]
# Out:
# ['god', 'goddess', 'satan', 'christ', 'deity']

# %% [markdown]
# #### Use PCA to breakdown the 400 dimensional vectors into 2 dimensions for plotting

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
emb_pca = pca.fit_transform(emb)

print(pca.explained_variance_ratio_)
print(pca.singular_values_)  
print(emb_pca.shape)
# Out:
# [0.57408 0.01101]
# [741.492   102.66906]
# (238462, 2)

# %% [markdown]
# ## Using Glove embeddings to find spelling errors

# %%
g_dim = 300 # the dimensionality of our glove vectors

# %% [markdown]
# Load via `np.loadtxt` (kernel dies for anything bigger than the 6B model)

# %%
# glove = np.loadtxt("data/glove/glove.42B.300d.txt", dtype='str', comments=None)

# %%
# words = glove[:, 0].tolist()
# vectors = glove[:, 1:].astype('float')

# %% [markdown]
# Load via pandas (works for **all** glove models)

# %%
glove_df = pd.read_table("data/glove/glove.42B.300d.txt", sep=" ", index_col=0, header=None, 
                         quoting=csv.QUOTE_NONE, na_values=None, keep_default_na=False)

len(glove_df)
# Out:
# 1917494

# %%
words = glove_df.index.values.tolist()
words[:5]
# Out:
# [',', 'the', '.', 'and', 'to']

# %%
vectors = glove_df.values
len(vectors[0])
# Out:
# 300

# %% [markdown]
# #### Instead of using sklearn, we'll try using nmslib instead

# %%
import nmslib

# %%
def create_index(a):
    # 1. create index on angular distance
    #index = nmslib.init(space='angulardist') 
    index = nmslib.init(method='hnsw', space='cosinesimil')
    
    index.addDataPointBatch(a)
    index.createIndex()
    return index

def get_knns(index, vecs, n_nn=8):
    # 3. can query a bunch of vectors all at once and get there "k" nearest neighbors
    return zip(*index.knnQueryBatch(vecs, k=n_nn, num_threads=4)) 

def get_knn(index, vec, n_nn=8): 
    return index.knnQuery(vec, k=n_nn)

def get_token_knns(index, tokens, n_nn=8):    
    vecs = [ vectors[words.index(t)] if t in words else np.zeros((g_dim)) for t in tokens ]
    return get_knns(index, vecs, n_nn)

# %%
# %time nms_idx = create_index(vectors) # 2. do it on all of our word vectors
# Out:
# CPU times: user 1h 37min 24s, sys: 57.8 s, total: 1h 38min 22s
# Wall time: 15min 47s

# %%
word_vec = vectors[words.index('god')]
word_vec.shape
# Out:
# (300,)

# %%
# 4. tells you their indexes and how far away they are
knn_idxs, knn_dists = get_knns(nms_idx, np.expand_dims(word_vec, 0))

# %%
knn_idxs, knn_dists, len(knn_idxs), len(knn_dists)
# Out:
# ((array([  344,  1849,  1371,  1368,  3097,  5764, 15099,  1734], dtype=int32),),
#  (array([0.     , 0.19305, 0.20231, 0.24353, 0.26355, 0.27491, 0.27819, 0.28092], dtype=float32),),
#  1,
#  1)

# %%
[[ words[idx] for idx in idxs ] for idxs in knn_idxs ]
# Out:
# [['god', 'christ', 'jesus', 'lord', 'heaven', 'gods', 'almighty', 'faith']]

# %% [markdown]
# #### Try finding spelling mistakes based on a transformation vector built from a single misspelling

# %% [markdown]
# Explore conclusions from here:  [NLP: Any libraries/dictionaries out there for fixing common spelling errors?](http://forums.fast.ai/t/nlp-any-libraries-dictionaries-out-there-for-fixing-common-spelling-errors/16411/8?u=wgpubs)

# %%
misspelled = ['realiable']

# %%
knn_idxs, knn_dists = get_token_knns(nms_idx, misspelled)

# %%
misspelled_words = []
d = collections.defaultdict(lambda: [])
for i, (idxs, dists) in enumerate(zip(knn_idxs, knn_dists)):
    for idx, dist in zip(idxs, dists):
        misspelled_words.append(words[idx])
        print(misspelled[i], words[idx], dist)
    print('')
# Out:
# realiable realiable 0.0
# realiable relaible 0.37913597
# realiable realible 0.47054034
# realiable reliabe 0.50882244
# realiable trust-worthy 0.515444
# realiable relieable 0.5173365
# realiable relaiable 0.527301
# realiable knowlegable 0.5483686

# %%
misspelled_words_vecs = np.array([ vectors[words.index(w)] for w in misspelled_words ])

# %%
misspelled_words_vecs.shape
# Out:
# (8, 300)

# %%
one_correct_word = vectors[words.index('reliable')]

# %%
one_xform_vec = (misspelled_words_vecs - one_correct_word).mean(axis=0)

# %%
one_xform_vec.shape
# Out:
# (300,)

# %% [markdown]
# Try using other *transformation vector* on a different misspelled word

# %%
new_vec = vectors[words.index('thier')] - one_xform_vec

# %%
knn_idxs, knn_dists = get_knns(nms_idx, np.expand_dims(new_vec, 0))
knn_idxs, knn_dists
# Out:
# ((array([   62, 14902,   205,    63,   193,    92,    32,   273], dtype=int32),),
#  (array([0.22198, 0.24216, 0.25902, 0.26866, 0.29234, 0.29627, 0.30234, 0.30454], dtype=float32),))

# %%
[[ words[idx] for idx in idxs ] for idxs in knn_idxs ]
# Out:
# [['their', 'thier', 'own', 'our', 'same', 'them', 'your', 'sure']]

# %% [markdown]
# There is is, the closest word ***is*** the correct spelling

# %% [markdown]
# #### Try finding misspellings based on an ensembled transformation vector

# %%
spelling_regex_repls = {
    # abbreviations
    r"\bacctg\b" : "acct",
    r"\badd'l\b" : "additional",
#     r"\br\s\b": "are",
#     r"\bu\s\b": "you ",
#     r"\b\sm\s\b ": "am",
#     r"'cause\b" : "because",
#     r"\b(ha)+\b": "haha",
#     r"\b(he)+\b": "haha",
#     r"\bya+y\b": "yay",
#     r"\bwa+y\b": "way",
    r"\bf'real\b" : "for real",
#     r"\bgr8\b" : "great",
    r"\bintl\b" : "int'l",
    # common misspellings
    r"\bbailable\b" : "available",
    r"\babilty\b" : "ability",
    r"\babsolutly\b" : "absolutely",
    r"\babsoultely\b" : "absolutely",
    r"\bacces\b" : "access",
    r"\baccesability\b" : "accessibility",
    r"\baccesbility\b" : "accessibility",
    r"\baccesibility\b" : "accessibility",
    r"\baccessability\b" : "accessibility",
    r"\baccessbility\b" : "accessibility",
    r"\baccesable\b" : "accessible",
    r"\baccesible\b" : "accessible",
    r"\baccessable\b" : "accessible",
    r"\bacessible\b" : "accessible",
    r"\bassessable\b" : "availability",
    r"\baccidently\b" : "accidentally",
    r"\baccomadate\b" : "accommodate",
    r"\baccomdate\b" : "accommodate",
    r"\baccomidate\b" : "accommodate",
    r"\baccomodate\b" : "accommodate",
    r"\baccomadating\b" : "accommodating",
    r"\baccomidating\b" : "accommodating",
    r"\baccomodating\b" : "accommodating",
    r"\baccomadations\b" : "accommodations",
    r"\baccomodation\b" : "accommodation",
    r"\baccouting\b" : "accounting",
    r"\baccross\b" : "across",
    r"\badd'l\b" : "additional",
    r"\badditonal\b" : "additional",
    r"\baddtionally\b" : "additionally",
    r"\badminstration\b" : "administration",
    r"\badminstrative\b" : "administrative",
    r"\badminstrator\b" : "administrator",
    r"\badress\b" : "address",
    r"\badvancment\b" : "advancement",
    r"\badvertized\b" : "advertised",
    r"\bafforable\b" : "affordable",
    r"\bafordable\b" : "affordable",
    r"\bafterall\b" : "after all",
    r"\bafterhours\b" : "after hours",
    r"\baggresive\b" : "aggressive",
    r"\bagressive\b" : "aggressive",
    r"\bagressions\b" : "aggressions",
    r"\balittle\b" : "a little",
    r"\balll\b" : "all",
    r"\balloted\b" : "allotted",
    r"\ballthough\b" : "although",
    r"\balthought\b" : "although",
    r"\ballways\b" : "always",
    r"\balos\b" : "also",
    r"\balot\b" : "a lot",
    r"\balotted\b" : "allotted",
    r"\bammount\b" : "amount",
    r"\bammounts\b" : "amounts",
    r"\bamoung\b" : "among",
    r"\bamoungst\b" : "amongst",
    r"\bannouncment\b" : "announcement",
    r"\baparments\b" : "apartments",
    r"\bapparrel\b" : "apparel",
    r"\bappartment\b" : "apartment",
    r"\bappriciate\b" : "appreciate",
    r"\bassitance\b" : "assistance",
    r"\bassitant\b" : "assistant",
    r"\batleast\b" : "at least",
    r"\battentative\b" : "attentive",
    r"\battrocious\b" : "atrocious",
    r"\bavaiable\b" : "available",
    r"\bavaible\b" : "available",
    r"\bavailabe\b" : "available",
    r"\bavailble\b" : "available",
    r"\bavailiable\b" : "available",
    r"\bavailible\b" : "available",
    r"\bavaliable\b" : "available",
    r"\bavalible\b" : "available",
    r"\bavilable\b" : "available",
    r"\bavailiability\b" : "availability",
    r"\bavailabiltiy\b" : "availability",
    r"\bavailabilty\b" : "availability",
    r"\bavailablility\b" : "availability",
    r"\bavailablity\b" : "availability",
    r"\bavailibility\b" : "availability",
    r"\bavaliability\b" : "availability",
    r"\bavaliablity\b" : "availability",
    r"\bavalibility\b" : "availability",
    r"\bactivies\b" : "activities",
    r"\bactivites\b" : "activities",
    r"\bactualy\b" : "actually",
    r"\bacutally\b" : "actually",
    r"\bammenities\b" : "amenities",
    r"\bantoher\b" : "another",
    r"\bassitant\b" : "assistant",
    r"\baswell\b" : "as well",
    r"\baweful\b" : "awful",
    r"\bawfull\b" : "awful",
    r"\bawsome\b" : "awesome",
    r"\bbeacuse\b" : "because",
    r"\bbearly\b" : "barely",
    r"\bbeaurocracy\b" : "bureaucracy",
    r"\bbeaurocratic\b" : "bureaucratic",
    r"\bbecasue\b" : "because",
    r"\bbecuase\b" : "because",
    r"\bbecuse\b" : "because",
    r"\bbefor\b" : "before",
    r"\bbeggining\b" : "beginning",
    r"\bbegining\b" : "beginning",
    r"\bbeleive\b" : "believe",
    r"\bbelive\b" : "believe",
    r"\bbenificial\b" : "beneficial",
    r"\bbenifit\b" : "benefit",
    r'\bbugetary\b' : "budgetary",
    r'\bbuiding\b' : "building",
    r'\bbuidling\b' : "building",
    r'\bbuisness\b' : "business",
    r'\bbuliding\b' : "building",
    r"\bbureacracy\b" : "bureaucracy",
    r"\bburitto\b" : "burrito",
    r"\bbussiness\b" : "business",
    r"\bcalender\b" : "calendar",
    r"\bcan;t\b" : "can't",
    r"\bcasher\b" : "cashier",
    r'\bcatagories\b' : "categories",
    r'\bcatagory\b' : "category",
    r"\bcheapter\b" : "cheaper",
    r"\bcheeper\b" : "cheaper",
    r'\bclasss\b' : "clas",
    r'\bclassses\b' : "classes",
    r"\bcleaniness\b" : "cleanliness",
    r"\bcmapus\b" : "campus",
    r'\bcofee\b' : "coffee",
    r'\bcoffe\b' : "coffee",
    r'\bcollegue\b' : "colleague",
    r'\bcoment\b' : "comment",
    r'\bcoments\b' : "comments",
    r'\bcomming\b' : "coming",
    r'\bcommittment\b' : "commitment",
    r'\bcommment\b' : "comment",
    r'\bcommuication\b' : "communication",
    r'\bcommunter\b' : "commuter",
    r'\bcommunters\b' : "commuters",
    r'\bcomotion\b' : "commotion",
    r'\bcomparision\b' : "comparison",
    r'\bcompatability\b' : "compatibility",
    r'\bcompatable\b' : "compatible",
    r'\bcompetative\b' : "competitive",
    r'\bcompetetive\b' : "competitive",
    r'\bcompetive\b' : "competitive",
    r'\bcompletly\b' : "completely",
    r"\bcomraderie\b" : "camaraderie",
    r'\bcomradery\b' : "camaraderie",
    r'\bcomunication\b' : "communication",
    r'\bcomunity\b' : "community",
    r'\bconcious\b' : "conscious",
    r'\bcondusive\b' : "conducive",
    r'\bconection\b' : "connection",
    r"\bconfortable\b" : "comfortable",
    r'\bconsistant\b' : "consistent",
    r'\bconsistantly\b' : "consistently",
    r'\bconsistenly\b' : "consistently",
    r'\bcontinously\b' : "continuously",
    r'\bcontruction\b' : "construction",
    r'\bconveinent\b' : "convenient",
    r'\bconveinient\b' : "convenient",
    r'\bconveniant\b' : "convenient",
    r'\bconveniece\b' : "convenience",
    r'\bconveninent\b' : "convenient",
    r'\bconvienance\b' : "convenience",
    r'\bconvienant\b' : "convenient",
    r'\bconvience\b' : "convenience",
    r'\bconvienence\b' : "convenience",
    r'\bconvienent\b' : "convenient",
    r'\bconvienet\b' : "convenient",
    r'\bconvienience\b' : "convenience",
    r'\bconvienient\b' : "convenient",
    r'\bconvient\b' : "convenient",
    r'\bconviently\b' : "conveniently",
    r'\bconvinence\b' : "convenience",
    r'\bconvinent\b' : "convenient",
    r'\bconvinience\b' : "convenience",
    r'\bconvinient\b' : "convenient",
    r'\bcorteous\b' : "courteous",
    r'\bcostodial\b' : "custodial",
    r'\bcoureous\b' : "courteous",
    r'\bcourtis\b' : "courteous",
    r'\bcouteous\b' : "courteous",
    r'\bcovenient\b' : "convenient",
    r'\bcroweded\b' : "crowded",
    r'\bcurteous\b' : "courteous",
    r'\bcurtesy\b' : "courtesy",
    r'\bcurtious\b' : "courteous",
    r"\bdeaprtment\b" : "department",
    r"\bdecission\b" : "decision",
    r'\bdefinately\b' : "definitely",
    r'\bdefinetely\b' : "definitely",
    r'\bdefinetly\b' : "definitely",
    r'\bdefinitley\b' : "definitely",
    r'\bdefinitly\b' : "definitely",
    r'\bdelievered\b' : "delivered",
    r'\bdeliverers\b' : "deliveries",
    r'\bdeparment\b' : "department",
    r'\bdeparments\b' : "department",
    r'\bdepartement\b' : "department",
    r"\bdepartment\(s\b" : "departments",
    r'\bdepartmet\b' : "department",
    r'\bdepratment\b' : "department",
    r"\bdeptartment\b" : "department",
    r'\bdescrimination\b' : "discrimination",
    r'\bdesireable\b' : "desirable",
    r"\bdiffernt\b" : "different",
    r"\bdiffrent\b" : "different",
    r'\bdinig\b' : "dining",
    r'\bdirverse\b' : "diverse",
    r'\bdisapointed\b' : "disappointed",
    r'\bdisapointing\b' : "disappointing",
    r'\bdisasterous\b' : "disastrous",
    r'\bdisatisfied\b' : "dissatisfied",
    r'\bdisbursment\b' : "disbursement",
    r'\bdisbursments\b' : "disbursements",
    r'\bdiscretely\b' : "discreetly",
    r'\bdiscusting\b' : "disgusting",
    r'\bdisfunctional\b' : "dysfunctional",
    r'\bdispensors\b' : "dispensers",
    r'\bdispersement\b' : "disbursement",
    r'\bdissapointed\b' : "disappointed",
    r'\bdissapointing\b' : "disappointing",
    r'\bdissapointment\b' : "disappointment",
    r'\bdissappointed\b' : "disappointed",
    r'\bdissappointing\b' : "disappointing",
    r'\bdissatified\b' : "dissatisfied",
    r'\bdiveristy\b' : "diversity",
    r'\bdivison\b' : "division",
    r'\bdivsion\b' : "division",
    r"\bdoens't\b" : "doesn't",
    r"\bdoes't\b" : "doesn't",
    r"\bdoesn;t\b" : "doesn't",
    r"\bdon;t\b" : "don't",
    r'\bdonot\b' : "do not",
    r"\bdosen't\b" : "doesn't",
    r"\bdosent\b" : "doesn't",
    r'\bdumbells\b' : "dumbbells",
    r'\bdurring\b' : "during",
    r"\beatting\b" : "eating",
    r"\beduation\b" : "education",
    r'\beffeciency\b' : "efficiency",
    r'\beffecient\b' : "efficient",
    r'\befficency\b' : "efficiency",
    r'\befficent\b' : "efficient",
    r'\beffiecient\b' : "efficient",
    r'\beimplying\b' : "implying",
    r'\bembarassed\b' : "embarrassed",
    r'\bembarassing\b' : "embarrassing",
    r'\bembarassment\b' : "embarrassment",
    r'\bemploee\b' : "employee",
    r'\bemploye\b' : "employee",
    r'\bemployee\(s\b' : "employees",
    r'\bemployeed\b' : "employed",
    r'\bemployement\b' : "employment",
    r'\bemployes\b' : "employees",
    r'\bemployess\b' : "employees",
    r'\bemplyee\b' : "employee",
    r'\bemplyees\b' : "employees",
    r'\bempolyees\b' : "employees",
    r'\bencoutered\b' : "encountered",
    r'\benought\b' : "enough",
    r'\benrollement\b' : "enrollment",
    r'\benviorment\b' : "environment",
    r'\benviornment\b' : "environment",
    r'\benvirnment\b' : "environment",
    r'\benviroment\b' : "environment",
    r'\benvironement\b' : "environment",
    r'\bequiped\b' : "equipped",
    r'\bespcially\b' : "especially",
    r'\bespecailly\b' : "especially",
    r'\bespecialy\b' : "especially",
    r'\bespeically\b' : "especially",
    r"\besthetically\b" : "aesthetically ",
    r"\bethinicity\b" : "ethnicity",
    r"\bevaulation\b" : "evaluation",
    r"\beventhough\b" : "even though",
    r'\beverday\b' : "every day",
    r'\beverthing\b' : "everything",
    r'\beveryones\b' : "everyones",
    r'\beverythings\b' : "everythings",
    r'\beveryway\b' : "every way",
    r'\beveyone\b' : "everyone",
    r'\beveything\b' : "everything",
    r'\bevrything\b' : "everything",
    r'\bexcelent\b' : "excellent",
    r'\bexcellant\b' : "excellent",
    r'\bexellent\b' : "excellent",
    r'\bexhorbitant\b' : "exorbitant",
    r'\bexistance\b' : "existence",
    r'\bexpecially\b' : "especially",
    r'\bexpensice\b' : "expensive",
    r'\bexpereince\b' : "experience",
    r'\bexperiance\b' : "experience",
    r'\bexperince\b' : "experience",
    r'\bexpierence\b' : "experience",
    r'\bexpirence\b' : "experience",
    r'\bexplaination\b' : "explanation",
    r'\bexremely\b' : "extremely",
    r'\bextemely\b' : "extremely",
    r'\bextention\b' : "extension",
    r'\bextermely\b' : "extremely",
    r'\bextreamly\b' : "extremely",
    r'\bextrememly\b' : "extremely",
    r'\bextremly\b' : "extremely",
    r"\bfacilites\b" : "facilities",
    r'\bfacilties\b' : "facilities",
    r'\bfacilty\b' : "facility",
    r'\bfaculity\b' : "faculty",
    r'\bfacutly\b' : "faculty",
    r'\bfiancial\b' : "financial",
    r"\bfinacial\b" : "financial",
    r"\bfirendly\b" : "friendly",
    r'\bflexability\b' : "flexibility",
    r'\bflexibilty\b' : "flexibility",
    r'\bflexiblity\b' : "flexibility",
    r"\bflourescent\b" : "fluorescent",
    r'\bfreindly\b' : "friendly",
    r'\bfreqency\b' : "frequency",
    r'\bfreqent\b' : "frequent",
    r'\bfriednly\b' : "friendly",
    r'\bfrusterating\b' : "frustrating",
    r'\bfrusturating\b' : "frustrating",
    r'\bfustrating\b' : "frustrating",
    r'\bgovenor\b' : "governor",
    r"\bgraffitti\b" : "graffiti",
    r"\bgrafitti\b" : "graffiti",
    r"\bgreatful\b" : "grateful",
    r"\bguarenteed\b" : "guaranteed",
    r"\bguidlines\b" : "guidelines",
    r"\bguranteed\b" : "guaranteed",
    r"\bhappend\b" : "happened",
    r'\bharrass\b' : "harass",
    r'\bharrassed\b' : "harassed",
    r'\bharrassing\b' : "harassing",
    r'\bharrassment\b' : "harassment",
    r"\bhavn't\b" : "haven't",
    r'\bhealtheir\b' : "healthier",
    r'\bhealthly\b' : "healthy",
    r'\bhealtier\b' : "healthier",
    r'\bhealty\b' : "healthy",
    r'\bheathy\b' : "healthy",
    r'\bheirarchy\b' : "hierarchy",
    r'\bhelful\b' : "helpful",
    r'\bhelpfull\b' : "helpful",
    r'\bhelpul\b' : "helpful",
    r'\bhighschool\b' : "high school",
    r'\bhighschools\b' : "high schools",
    r'\bhorendous\b' : "horrendous",
    r'\bhorible\b' : "horrible",
    r'\bhouseing\b' : "housing",
    r'\bi"m\b' : "i'm",
    r'\bi"ve\b' : "i've",
    r'\bimplimented\b' : "implemented",
    r'\bimporve\b' : "improve",
    r'\bimposible\b' : "impossible",
    r'\bimprovment\b' : "improvement",
    r'\bimprovments\b' : "improvements",
    r'\bincompetant\b' : "incompetent",
    r'\binconsistant\b' : "inconsistent",
    r'\binconveinent\b' : "nconvenient",
    r'\binconvience\b' : "inconvenience",
    r'\binconvienent\b' : "nconvenient",
    r'\binconvienient\b' : "nconvenient",
    r'\binconvient\b' : "nconvenient",
    r'\binconvinient\b' : "nconvenient",
    r'\bindentify\b' : "identify",
    r'\bindependant\b' : "independent",
    r'\bindividual\(s\b' : "individuals",
    r'\binforced\b' : "enforced",
    r'\binformaiton\b' : "information",
    r'\binformtion\b' : "information",
    r'\binfront\b' : "in front",
    r'\binnout\b' : "in-n-out",
    r'\binsentive\b' : "incentive",
    r'\binsufficent\b' : "insufficient",
    r'\binterenet\b' : "internet",
    r'\binterent\b' : "internet",
    r'\bintermural\b' : "intramural",
    r'\bintramurals\b' : "intramurals",
    r'\binvironment\b' : "environment",
    r'\bissue\(s\b' : "issues",
    r'\bit;s\b' : "it's",
    r'\bitem\(s\b' : "items",
    r"\bjob\(s\b" : "jobs",
    r'\bknowledable\b' : "knowledgeable",
    r'\bknowledeable\b' : "knowledgeable",
    r'\bknowledegable\b' : "knowledgeable",
    r'\bknowledgable\b' : "knowledgeable",
    r'\bknowledgably\b' : "knowledgeably",
    r'\bknowledgeably\b' : "knowledgeably",
    r'\bknowledgeble\b' : "knowledgeable",
    r'\bknowlegable\b' : "knowledgeable",
    r'\bknowlegeable\b' : "knowledgeable",
    r'\bliek\b' : "like",
    r'\blieke\b' : "like",
    r'\blimted\b' : "limited",
    r'\bmaintainance\b' : "maintenance",
    r'\bmaintaince\b' : "maintenance",
    r'\bmaintainence\b' : "maintenance",
    r'\bmaintanance\b' : "maintenance",
    r'\bmaintance\b' : "maintenance",
    r'\bmaintanence\b' : "maintenance",
    r'\bmaintenace\b' : "maintenance",
    r'\bmaintenances\b' : "maintenance",
    r'\bmaintence\b' : "maintenance",
    r'\bmaintenece\b' : "maintenance",
    r'\bmaintenence\b' : "maintenance",
    r'\bmaitenance\b' : "maintenance",
    r'\bmanager\(s\b' : "managers",
    r'\bmanagment\b' : "management",
    r'\bmanangement\b' : "management",
    r'\bmangement\b' : "management",
    r'\bmangers\b' : "managers",
    r'\bmanuever\b' : "maneuver",
    r'\bmintues\b' : "minutes",
    r'\bmoblie\b' : "mobile",
    r'\bmulitple\b' : "multiple",
    r'\bn\?a\b' : "n/a",
    r'\bna\b' : "n/a",
    r'\bneccessary\b' : "necessary",
    r'\bnecesary\b' : "necessary",
    r'\bneedes\b' : "needs",
    r'\bneeed\b' : "need",
    r'\bnonexistant\b' : "nonexistent",
    r'\bnothig\b' : "nothing",
    r'\bnothjng\b' : "nothing",
    r'\bnoticable\b' : "noticeable",
    r'\bobsurd\b' : "absurd",
    r'\bocassional\b' : "occasional",
    r'\boccassion\b' : "occasion",
    r'\boccassional\b' : "occasional",
    r'\boccassionally\b' : "occasionally",
    r'\boccassions\b' : "occasions",
    r'\boccations\b' : "occasions",
    r'\boccurances\b' : "occurrences",
    r'\boccured\b' : "occurred",
    r'\boccuring\b' : "occurring",
    r'\boccurr\b' : "occur",
    r'\bofcourse\b' : "of course",
    r'\bofferred\b' : "offered",
    r'\bopinon\b' : "opinion",
    r'\bopitions\b' : "options",
    r'\boportunities\b' : "opportunities",
    r'\bopperation\b' : "operation",
    r'\boppertunities\b' : "opportunities",
    r'\boppinion\b' : "opinion",
    r'\bopportunites\b' : "opportunities",
    r'\bopportunties\b' : "opportunities",
    r'\boppotunities\b' : "opportunities",
    r'\boppurtunities\b' : "opportunities",
    r'\boppurtunity\b' : "opportunity",
    r'\borgnized\b' : "organized",
    r'\boutragous\b' : "outrageous",
    r'\bpage\(s\b' : "pages",
    r'\bpakages\b' : "packages",
    r'\bparkibg\b' : "parking",
    r'\bparkig\b' : "parking",
    r'\bparkign\b' : "parking",
    r'\bparkinglots\b' : "parking lots",
    r'\bpartime\b' : "part-time",
    r'\bparttime\b' : "part-time",
    r'\bpatroling\b' : "patrolling",
    r'\bpeopel\b' : "people",
    r'\bpermitt\b' : "permit",
    r'\bperson\(s\b' : "persons",
    r'\bpersonel\b' : "personnel",
    r'\bpersonell\b' : "personnel",
    r'\bpharamcy\b' : "pharmacy",
    r'\bpleasent\b' : "pleasant",
    r'\bplently\b' : "plenty",
    r'\bplesant\b' : "pleasant",
    r'\bpositon\b' : "position",
    r'\bposses\b' : "possess",
    r'\bpossition\b' : "position",
    r'\bpostion\b' : "position",
    r'\bpostions\b' : "positions",
    r'\bpostition\b' : "position",
    r'\bpostive\b' : "positive",
    r'\bpractioner\b' : "practitioner",
    r'\bpractioners\b' : "practitioners",
    r'\bprefered\b' : "preferred",
    r'\bpreferrably\b' : "preferably",
    r'\bpreform\b' : "perform",
    r'\bpreforming\b' : "performing",
    r'\bpricess\b' : "prices",
    r'\bpriciples\b' : "principles",
    r'\bpricy\b' : "pricey",
    r'\bprking\b' : "parking",
    r'\bproceedures\b' : "procedures",
    r'\bprocurment\b' : "procurement",
    r'\bprofessionaly\b' : "professionally",
    r'\bproffessional\b' : "professional",
    r'\bproffit\b' : "profit",
    r'\bprofitt\b' : "profit",
    r'\bprogam\b' : "program",
    r'\bpromissed\b' : "promised",
    r'\bpublically\b' : "publicly",
    r'\bqucik\b' : "quick",
    r'\bquestion\(s\b' : "questions",
    r'\bquestionaire\b' : "questionnaire",
    r'\breall\b' : "really",
    r'\brealy\b' : "really",
    r'\breccomend\b' : "recommend",
    r'\breccommend\b' : "recommend",
    r'\breceieve\b' : "receive",
    r'\breciept\b' : "receipt",
    r'\breciepts\b' : "receipts",
    r'\brecieve\b' : "receive",
    r'\brecieved\b' : "received",
    r'\brecieves\b' : "receives",
    r'\brecieving\b' : "receiving",
    r'\brecived\b' : "received",
    r'\brecomend\b' : "recommend",
    r'\brecomended\b' : "recommended",
    r'\brediculous\b' : "ridiculous",
    r'\brediculously\b' : "ridiculously",
    r'\brefered\b' : "referred",
    r'\brefering\b' : "referring",
    r'\bregeants\b' : "regents",
    r'\bregistar\b' : "regisrtar",
    r'\bregistars\b' : "regisrtars",
    r'\bregulary\b' : "regularly",
    r'\breimbursment\b' : "reimbursement",
    r'\breponse\b' : "response",
    r'\breponsive\b' : "responsive",
    r'\brepresentitive\b' : "representative",
    r'\breserach\b' : "research",
    r'\bresonable\b' : "reasonable",
    r'\bresouces\b' : "resources",
    r'\bresourses\b' : "resources",
    r'\bresponsed\b' : "responded",
    r'\bresponsibilites\b' : "responsibilites",
    r'\bresponsiblities\b' : "responsibilites",
    r'\bresponsiblity\b' : "responsibility",
    r'\brestaraunts\b' : "restaurants",
    r'\brestraunts\b' : "restaurants",
    r'\brestuarant\b' : "restaurant",
    r'\brestuarants\b' : "restaurants",
    r'\bresturant\b' : "restaurant",
    r'\bresturants\b' : "restaurants",
    r'\bridiculus\b' : "ridiculous",
    r'\briduculous\b' : "ridiculous",
    r'\broomate\b' : "roommate",
    r'\broomates\b' : "roommates",
    r'\bsaleries\b' : "salaries",
    r'\bsandwhich\b' : "sandwich",
    r'\bsandwhiches\b' : "sandwiches",
    r'\bsandwitches\b' : "sandwiches",
    r'\bsatifaction\b' : "satisfaction",
    r'\bsatified\b' : "satisfisatisfieded",
    r'\bsattelite\b' : "satellite",
    r'\bsceience\b' : "science",
    r'\bschedual\b' : "schedule",
    r'\bseemless\b' : "seamless",
    r'\bselction\b' : "selection",
    r'\bsenority\b' : "seniority",
    r'\bsensative\b' : "sensitive",
    r'\bsensored\b' : "censored",
    r'\bseperate\b' : "separate",
    r'\bseperation\b' : "separation",
    r'\bserivce\b' : "service",
    r'\bserivces\b' : "services",
    r'\bserive\b' : "service",
    r'\bserives\b' : "services",
    r'\bservicesi\b' : "services",
    r'\bservidces\b' : "services",
    r'\bservive\b' : "survive",
    r'\bservives\b' : "survives",
    r'\bseverly\b' : "severely",
    r'\bsevice\b' : "service",
    r'\bsevices\b' : "services",
    r'\bshcool\b' : "school",
    r'\bshoud\b' : "should",
    r'\bshoudl\b' : "should",
    r'\bshutttle\b' : "shuttle",
    r'\bsimiliar\b' : "similar",
    r'\bsomeitmes\b' : "sometimes",
    r'\bsomeone\(s\b' : "someones",
    r'\bsomeones\b' : "someones",
    r'\bsometiems\b' : "sometimes",
    r'\bsomone\b' : "someone",
    r'\bsomthing\b' : "something",
    r'\bsophmore\b' : "sophomore",
    r'\bspecialy\b' : "especially",
    r'\bstafff\b' : "staff",
    r'\bstatment\b' : "statement",
    r'\bstong\b' : "strong",
    r'\bstongly\b' : "strongly",
    r'\bstoping\b' : "stopping",
    r'\bstrabucks\b' : "starbucks",
    r'\bstressfull\b' : "stressful",
    r'\bstructure\(s\b' : "structures",
    r'\bstucture\b' : "structure",
    r'\bstuctures\b' : "structures",
    r'\bstuden\b' : "student",
    r'\bstudent\(s\b' : "students",
    r'\bstudetns\b' : "students",
    r'\bstudnet\b' : "student",
    r'\bstudnets\b' : "students",
    r'\bsucess\b' : "success",
    r'\bsudent\b' : "student",
    r'\bsudents\b' : "students",
    r'\bsuperintendant\b' : "superintendent",
    r'\bsuperviser\b' : "supervisor",
    r'\bsupervisor\(s\b' : "supervisors",
    r'\bsupervisores\b' : "supervisors",
    r'\bsuport\b' : "support",
    r'\bsupples\b' : "supplies",
    r'\bsuppossed\b' : "supposed",
    r'\bsuprised\b' : "surprised",
    r'\bsuvey\b' : "survey",
    r'\bsytem\b' : "system",
    r'\bthats\b' : "that's",
    r"\bthe're\b" : "they're",
    r'\btheives\b' : "thieves",
    r'\bthiefs\b' : "thieves",
    r'\bthreating\b' : "threatening",
    r'\bthroughly\b' : "thoroughly",
    r'\bthrought\b' : "throughout",
    r'\bthroughtout\b' : "throughout",
    r'\btodays\b' : "today's",
    r'\btraing\b' : "training",
    r'\btrainning\b' : "training",
    r'\btranfers\b' : "transfers",
    r'\btransfered\b' : "transferred",
    r'\btransfering\b' : "transferring",
    r'\btransporation\b' : "transportation",
    r'\btransportaion\b' : "transportation",
    r'\btransportations\b' : "transportations",
    r'\btransportion\b' : "transportation",
    r'\btrashbags\b' : "trash bags",
    r'\btrashcans\b' : "trash cans",
    r'\btremedously\b' : "tremendously",
    r'\btshirt\b' : "t-shirt",
    r'\btshirts\b' : "t-shirts",
    r'\btution\b' : "tuition",
    r'\btutition\b' : "tuition",
    r'\bunaccessible\b' : "inaccessible",
    r'\bunconvenient\b' : "inconvenient",
    r'\bunecessary\b' : "unnecessary",
    r'\bunflexible\b' : "inflexible",
    r'\bunforseen\b' : "unforeseen",
    r'\buniverisity\b' : "university",
    r'\buniveristy\b' : "university",
    r'\buniverity\b' : "university",
    r'\bunknowledgeable\b' : "unknowledgable",
    r'\bunneccessary\b' : "unnecessary",
    r'\bunrealiable\b' : "unreliable",
    r'\buntill\b' : "until",
    r'\bunversity\b' : "university",
    r'\buseability\b' : "usability",
    r'\busefull\b' : "useful",
    r'\bususally\b' : "usually",
    r'\bvaccum\b' : "vacuum",
    r'\bvaccuum\b' : "vacuum",
    r'\bvaction\b' : "vacation",
    r'\bvacume\b' : "vacuum",
    r'\bvariaty\b' : "variety",
    r'\bvarities\b' : "varieties",
    r'\bvarity\b' : "variety",
    r'\bvegeterian\b' : "vegetarian",
    r'\bvegitarian\b' : "vegetarian",
    r'\bvegitarians\b' : "vegetarians",
    r'\bvegtables\b' : "vegetables",
    r'\bventillation\b' : "ventilation",
    r'\bveriety\b' : "variety",
    r'\bvisted\b' : "visited",
    r'\bvistor\b' : "visitor",
    r'\bvistors\b' : "visitors",
    r'\bweeekends\b' : "weekends",
    r'\bwierd\b' : "weird",
    r'\bwirless\b' : "wireless",
    r'\bwithdrawl\b' : "withdrawal",
    r'\bwoudl\b' : "would",
    r"\bwoudn't\b" : "wouldn't",
    r"\bthier\b" : "their",
    r"\bappartments\b" : "apartments",
    r"\bbenifits\b" : "benefits",
    r"\bexistant\b" : "existent",
    r"\bsaftey\b" : "safety",
    r'\bdon"t\b' : "don't",
}

# %%
# misspelled = ['realiable', 'becuase', 'definately', 'consistant']
# correct = ['reliable', 'because', 'definitely', 'consistent']

# %%
misspelled = []
correct = []

for k,v in spelling_regex_repls.items():
    tok = k.replace('\\b', '')
    if (not tok in words or not v in words): continue
        
    misspelled.append(tok)
    correct.append(v)

# %%
len(misspelled), len(correct)
# Out:
# (602, 602)

# %%
knn_idxs, knn_dists = get_token_knns(nms_idx, misspelled)

# %%
d = collections.defaultdict(lambda: [])

for i, (idxs, dists) in enumerate(zip(knn_idxs, knn_dists)):
    misspelled_words = []
    for idx, dist in zip(idxs, dists):
        misspelled_words.append(words[idx])
        print(misspelled[i], words[idx], dist)
    
    d[correct[i]] = misspelled_words
    print('')
# Out:
# acctg acctg 0.0
# acctg acctng 0.5503459
# acctg accouting 0.58349955
# acctg controllership 0.61513233
# acctg badm 0.6503613
# acctg acct 0.6698546
# acctg finanacial 0.6915154
# acctg buad 0.6962557
#
# bailable bailable -5.9604645e-07
# bailable non-bailable 0.47395074
# bailable non-cognizable 0.554535
# bailable cognisable 0.6377856
# bailable extraditable 0.6705159
# bailable offence 0.67171013
# bailable indictable 0.6843919
# bailable cautionable 0.6849176
#
# abilty abilty -3.5762787e-07
# abilty ablility 0.3382318
# abilty ablity 0.4068669
# abilty abillity 0.41447353
# abilty abiltiy 0.4155413
# abilty abililty 0.4488775
# abilty abilitiy 0.49680865
# abilty abilityto 0.56547153
#
# absolutly absolutly 2.3841858e-07
# absolutly absolutley 0.16695768
# absolutly absoultely 0.3163358
# absolutly absoloutely 0.33011663
# absolutly absoutely 0.3405972
# absolutly absolutely 0.35008812
# absolutly absolutey 0.3687563
# absolutly absoloutly 0.36960322
#
# absoultely absoultely 0.0
# absoultely absoloutely 0.22947705
# absoultely absoulutely 0.23117912
# absoultely absolutley 0.24187255
# absoultely aboslutely 0.25743532
# absoultely absoutely 0.2595802
# absoultely absoloutly 0.2599051
# absoultely absolutey 0.26772624
#
# acces acces 5.9604645e-08
# acces acess 0.3563828
# acces access 0.5149341
# acces acce 0.53070754
# acces acccess 0.55066407
# acces accsess 0.59335697
# acces wifi 0.6375517
# acces conection 0.6393163
#
# accesability accesability -2.3841858e-07
# accesability operationality 0.4801495
# accesability predicability 0.49330598
# accesability digestability 0.49742424
# accesability tidyness 0.49761498
# accesability cozyness 0.5068326
# accesability comfortness 0.5079217
# accesability sensibleness 0.5083622
#
# accesibility kazez 0.82854855
# accesibility tonomura 0.82889986
# accesibility fuleihan 0.83475304
# accesibility léveillé 0.84759295
# accesibility hokka 0.8523667
# accesibility origano 0.8583683
# accesibility reuveni 0.86046934
# accesibility couplin 0.8726698
#
# accessability accessability 0.0
# accessability accessibilty 0.5460423
# accessability accessibility 0.5509811
# accessability useability 0.574409
# accessability accessiblity 0.5758873
# accessability user-friendliness 0.6090426
# accessability customizability 0.61359394
# accessability navigability 0.61801434
#
# accessbility naturebeautiful 0.52838826
# accessbility 192/1000 0.53116304
# accessbility border='0' 0.53434336
# accessbility showcaseyourmusic.com 0.5397607
# accessbility +1,000,000.00 0.5404204
# accessbility crossed-flag-pins 0.54166913
# accessbility flash.filters.bevelfilter 0.54828435
# accessbility 2010-oct-06 0.550051
#
# accesable accesable 1.1920929e-07
# accesable acessable 0.41482937
# accesable accesible 0.4315197
# accesable accessable 0.43944597
# accesable acessible 0.45570654
# accesable accessbile 0.5013688
# accesable accesssible 0.5345003
# accesable reacheable 0.5455425
#
# accesible seguro 0.7357043
# accesible gratuita 0.7362206
# accesible clic 0.74256086
# accesible guía 0.7455208
# accesible hoteles 0.7524172
# accesible rivadavia 0.7676897
# accesible hostal 0.77191865
# accesible hogar 0.7730152
#
# accessable accessable 1.7881393e-07
# accessable accesible 0.22925663
# accessable accessible 0.36321497
# accessable accesable 0.43944597
# accessable reachable 0.4518987
# accessable acessible 0.48907888
# accessable findable 0.5044364
# accessable acessable 0.52229124
#
# acessible acessible 0.0
# acessible accesible 0.44317102
# acessible accesable 0.45570654
# acessible accessable 0.48907888
# acessible accesssible 0.50866306
# acessible acessable 0.51296556
# acessible assessible 0.52354634
# acessible accessibly 0.5457697
#
# assessable assessable 2.3841858e-07
# assessable taxable 0.50695634
# assessable imputed 0.56249833
# assessable reportable 0.5680327
# assessable distributable 0.5690973
# assessable chargeable 0.57614255
# assessable accruing 0.5799942
# assessable realisable 0.59215546
#
# accidently accidently -2.3841858e-07
# accidently accidentally 0.11997473
# accidently accidentaly 0.2891912
# accidently inadvertently 0.29480118
# accidently inadvertantly 0.33019036
# accidently unintentionally 0.39773625
# accidently mistakenly 0.43285918
# accidently unknowingly 0.4336229
#
# accomadate accomadate 1.7881393e-07
# accomadate accomidate 0.2759806
# accomadate accomodate 0.323434
# accomadate accomdate 0.3798406
# accomadate accomodated 0.40840983
# accomadate acommodate 0.43993658
# accomadate accommadate 0.46216154
# accomadate accomodates 0.5064999
#
# accomdate accomdate 2.3841858e-07
# accomdate accomadate 0.3798406
# accomdate acommodate 0.38031274
# accomdate accommadate 0.42217386
# accomdate accomidate 0.4367742
# accomdate acomodate 0.4992907
# accomdate satisify 0.51064
# accomdate accomidated 0.5214077
#
# accomidate accomidate -1.1920929e-07
# accomidate accomadate 0.2759806
# accomidate accomodate 0.3483112
# accomidate accomdate 0.4367742
# accomidate acommodate 0.44391555
# accomidate accomodated 0.46867245
# accomidate accomodates 0.49870235
# accomidate accommadate 0.5332556
#
# accomodate accomodate -8.34465e-07
# accomodate accommodate 0.14201695
# accomodate accomadate 0.323434
# accomodate accommodated 0.3467232
# accomodate accomidate 0.3483112
# accomodate accommodates 0.3621227
# accomodate cater 0.37154067
# accomodate accommodating 0.39770412
#
# accomadating accomadating 5.364418e-07
# accomadating accomidating 0.22211367
# accomadating accomodating 0.25558752
# accomadating accomdating 0.33246052
# accomadating accommadating 0.3941993
# accomadating acommodating 0.40277517
# accomadating corteous 0.41318733
# accomadating attentative 0.4394517
#
# accomidating accomidating 2.3841858e-07
# accomidating accomadating 0.22211367
# accomidating accomdating 0.33942825
# accomidating accomodating 0.34858865
# accomidating acommodating 0.37239647
# accomidating corteous 0.3772195
# accomidating accommadating 0.3887962
# accomidating attentative 0.39864737
#
# accomodating accomodating 1.1920929e-07
# accomodating accommodating 0.2372905
# accomodating accomadating 0.25558752
# accomodating accomidating 0.34858865
# accomodating obliging 0.3504225
# accomodating hospitable 0.36975825
# accomodating attentive 0.38619524
# accomodating courteous 0.3954625
#
# accomadations accomadations -1.1920929e-07
# accomadations accomidations 0.482749
# accomadations accomidation 0.51263636
# accomadations forhotels 0.55364716
# accomadations accomadation 0.5787375
# accomadations accomodations 0.58080065
# accomadations accommadations 0.60524136
# accomadations accommadation 0.64800453
#
# accomodation accomodation -1.1920929e-07
# accomodation accommodation 0.29376113
# accomodation accomodations 0.36586457
# accomodation accommodations 0.3970577
# accomodation hostels 0.423535
# accomodation lodging 0.4315927
# accomodation accomadation 0.44046974
# accomodation hostel 0.45795733
#
# accouting accouting 2.3841858e-07
# accouting acconting 0.51822776
# accouting acounting 0.5693922
# accouting bookeeping 0.5784891
# accouting acctg 0.58349955
# accouting bookkeeping 0.6168927
# accouting enginnering 0.6181303
# accouting job-costing 0.6183134
#
# accross accross 2.9802322e-07
# accross acroos 0.36856502
# accross across 0.37787092
# accross acrossed 0.41071743
# accross acorss 0.42604196
# accross acrosss 0.46016222
# accross arround 0.47048014
# accross throught 0.50207955
#
# additonal additonal 0.0
# additonal addtional 0.4029957
# additonal aditional 0.41198784
# additonal addional 0.47516853
# additonal additinal 0.4952029
# additonal additional 0.52882135
# additonal additionnal 0.5424963
# additonal upcharge 0.55114824
#
# addtionally addtionally -4.7683716e-07
# addtionally conversley 0.47848475
# addtionally 3dly 0.48754096
# addtionally moreoever 0.49034667
# addtionally furhtermore 0.49788117
# addtionally further-more 0.5083579
# addtionally morover 0.5187307
# addtionally furthmore 0.51974976
#
# adminstration adminstration -1.1920929e-07
# adminstration administration 0.4237315
# adminstration adminsitration 0.42604852
# adminstration admistration 0.4329812
# adminstration administration.the 0.44990206
# adminstration administation 0.45683777
# adminstration administraion 0.47944987
# adminstration administrations 0.49635565
#
# adminstrative adminstrative 5.9604645e-08
# adminstrative administative 0.47466058
# adminstrative adminsitrative 0.4929257
# adminstrative administrative 0.5066391
# adminstrative admistrative 0.58186674
# adminstrative assistant/receptionist 0.5861516
# adminstrative managerdelaware 0.59210193
# adminstrative administrational 0.5997978
#
# adminstrator adminstrator -2.3841858e-07
# adminstrator admistrator 0.50350404
# adminstrator administrator 0.55773157
# adminstrator administator 0.57781875
# adminstrator sysdba 0.63218737
# adminstrator priviledges 0.6582653
# adminstrator aspnet 0.66092443
# adminstrator superuser 0.67905533
#
# adress adress 0.0
# adress address 0.39391983
# adress adresses 0.4820397
# adress addres 0.48680723
# adress email 0.49337292
# adress adres 0.49755132
# adress e-mail 0.5134965
# adress addresses 0.5204512
#
# advancment advancment 1.1920929e-07
# advancment tecnological 0.609842
# advancment spie-int 0.6199915
# advancment opportunitites 0.62443006
# advancment techological 0.62520874
# advancment allergy/asthma 0.6331667
# advancment engineeer 0.6359284
# advancment technolgical 0.6456302
#
# advertized advertized -2.3841858e-07
# advertized adverstised 0.5149372
# advertized decribed 0.51712096
# advertized discribed 0.5180785
# advertized advertised 0.5283636
# advertized descibed 0.53294253
# advertized desribed 0.5680716
# advertized descriped 0.5687713
#
# afforable afforable -3.5762787e-07
# afforable affodable 0.36471355
# afforable afordable 0.41627818
# afforable afforadable 0.44306946
# afforable affordble 0.4887464
# afforable affordabe 0.50123346
# afforable affortable 0.5234525
# afforable affordible 0.52477264
#
# afordable afordable 0.0
# afordable afforable 0.41627818
# afordable cheepest 0.4321187
# afordable lowcost 0.44663024
# afordable affodable 0.48227805
# afordable creditcards 0.49487203
# afordable applicarions 0.49556875
# afordable quatation 0.5204946
#
# aggresive aggresive 2.3841858e-07
# aggresive agressive 0.11652523
# aggresive aggressive 0.3965596
# aggresive non-aggressive 0.46912074
# aggresive assertive 0.47150552
# aggresive in-your-face 0.49458176
# aggresive confrontational 0.5035274
# aggresive pushy 0.5298994
#
# agressive agressive 2.3841858e-07
# agressive aggresive 0.11652523
# agressive aggressive 0.24114835
# agressive assertive 0.40752113
# agressive non-aggressive 0.43829983
# agressive confrontational 0.44549495
# agressive in-your-face 0.45720673
# agressive pushy 0.4818521
#
# agressions évolutions 0.6091418
# agressions espagnols 0.64412063
# agressions individus 0.6482068
# agressions ennuis 0.65208244
# agressions autorités 0.65740836
# agressions édifices 0.65896934
# agressions terroristes 0.6603856
# agressions peurs 0.66520965
#
# alll alll 5.9604645e-08
# alll allll 0.2971388
# alll alllll 0.31809926
# alll allllll 0.35519105
# alll alllllll 0.41223085
# alll thse 0.439075
# alll yall 0.4611721
# alll thoes 0.46443403
#
# alloted alloted 5.9604645e-08
# alloted allotted 0.19891143
# alloted alotted 0.2754197
# alloted allotting 0.49323136
# alloted allocated 0.5054269
# alloted amout 0.5171453
# alloted allocate 0.5553191
# alloted allotment 0.56756496
#
# allthough allthough -1.1920929e-07
# allthough althought 0.22446412
# allthough altough 0.23093599
# allthough altho 0.31380326
# allthough unfortunatley 0.35152864
# allthough eventhough 0.35903108
# allthough athough 0.36137652
# allthough unfortunatly 0.3828721
#
# althought althought 1.7881393e-07
# althought altough 0.162812
# althought altho 0.19093049
# althought eventhough 0.2047844
# althought allthough 0.22446412
# althought unfortunatly 0.2657473
# althought unfortunatley 0.26849198
# althought athough 0.30329967
#
# allways allways -8.34465e-07
# allways alway 0.3454817
# allways alwasy 0.3971889
# allways definatly 0.4138326
# allways definitly 0.41609585
# allways jsut 0.42168254
# allways alwys 0.42182416
# allways realy 0.4229884
#
# alos alos 5.9604645e-07
# alos acutally 0.520584
# alos actally 0.52667165
# alos allso 0.53723115
# alos acually 0.54277474
# alos acctually 0.54774463
# alos alwasy 0.55707467
# alos actaully 0.5591901
#
# alotted alotted -3.5762787e-07
# alotted alloted 0.2754197
# alotted allotted 0.42930388
# alotted elasped 0.5652689
# alotted wasteing 0.5682073
# alotted aloted 0.5758495
# alotted ittakes 0.5821635
# alotted ads2 0.58429694
#
# ammount ammount 1.1920929e-07
# ammount amout 0.26815712
# ammount amountof 0.4832617
# ammount amoutn 0.48950022
# ammount ammounts 0.52313995
# ammount amoount 0.5325183
# ammount amount 0.5518377
# ammount enought 0.5659381
#
# ammounts ammounts 2.3841858e-07
# ammounts amouts 0.39428216
# ammounts amout 0.46098113
# ammounts amoutn 0.49601674
# ammounts ammount 0.52313995
# ammounts amound 0.5311059
# ammounts quanities 0.5319542
# ammounts amoount 0.5477296
#
# amoung amoung -4.7683716e-07
# amoung amonst 0.38911653
# amoung amongs 0.43803823
# amoung amongst 0.45085657
# amoung amongest 0.49078375
# amoung among 0.5198921
# amoung amogst 0.56889904
# amoung amongthe 0.59535205
#
# amoungst amongst 0.65244484
# amoungst amoung 0.6654916
# amoungst them.the 0.69141376
# amoungst years.and 0.6974518
# amoungst us.the 0.71349347
# amoungst among 0.7164452
# amoungst consorted 0.71736807
# amoungst years.the 0.72165656
#
# announcment announcment 3.5762787e-07
# announcment annoucement 0.26565492
# announcment anouncement 0.27635264
# announcment anouncment 0.544977
# announcment announement 0.54725206
# announcment annoucment 0.5562589
# announcment announcemnt 0.56624866
# announcment annoucements 0.57113683
#
# aparments aparments 5.9604645e-08
# aparments aprtments 0.56839085
# aparments 2-bedrooms 0.6140622
# aparments apartements 0.6211495
# aparments apartments 0.63556844
# aparments apartmens 0.63588846
# aparments apartmetns 0.6444322
# aparments 2bdr 0.65101755
#
# apparrel 0-home 0.7109467
# apparrel lightingcapital 0.7197984
# apparrel lightingblauet 0.7217017
# apparrel support/services 0.7254604
# apparrel clivedon 0.73308146
# apparrel environment-oriented 0.73545134
# apparrel katholik 0.736058
# apparrel lightingcorbett 0.7384646
#
# appartment appartment -1.1920929e-07
# appartment apartment 0.36979383
# appartment townhouse 0.45873082
# appartment aparment 0.48067194
# appartment appartments 0.4808811
# appartment condo 0.4918595
# appartment annexe 0.5096849
# appartment furnished 0.51267135
#
# appriciate appriciate -4.7683716e-07
# appriciate apreciate 0.2563212
# appriciate appreicate 0.32483882
# appriciate appreaciate 0.34382772
# appriciate apperciate 0.36087972
# appriciate appricate 0.36966002
# appriciate appretiate 0.37237668
# appriciate apprciate 0.3823955
#
# assitance assitance -1.1920929e-07
# assitance assistence 0.34634817
# assitance asistance 0.42652136
# assitance guidence 0.5111816
# assitance help.the 0.51571804
# assitance assistance 0.5220068
# assitance assistances 0.52691984
# assitance assisstance 0.5476504
#
# assitant assitant 2.3841858e-07
# assitant assisstant 0.37117225
# assitant asistant 0.3761655
# assitant assisant 0.4226827
# assitant assistent 0.45779723
# assitant asst. 0.48771226
# assitant assistant 0.4919145
# assitant assistan 0.5001139
#
# attentative attentative 1.7881393e-07
# attentative corteous 0.31614846
# attentative accomdating 0.35871744
# attentative couteous 0.36941254
# attentative friendly/helpful 0.39165914
# attentative accommadating 0.39319968
# attentative acommodating 0.39475262
# attentative accomidating 0.39864737
#
# attrocious attrocious 0.0
# attrocious appauling 0.4192176
# attrocious appaling 0.43080646
# attrocious atrocious 0.47055697
# attrocious apalling 0.52470154
# attrocious dispicable 0.527305
# attrocious unforgiveable 0.53910935
# attrocious horrable 0.5490427
#
# avaiable avaiable 0.0
# avaiable avaliable 0.30059826
# avaiable avaible 0.32916415
# avaiable availble 0.33695322
# avaiable avalible 0.3527674
# avaiable avilable 0.35613585
# avaiable availible 0.3614871
# avaiable availiable 0.39666396
#
# avaible avaible -2.3841858e-07
# avaible avalible 0.23999822
# avaible avilable 0.2690388
# avaible avaliable 0.27691287
# avaible availible 0.28141564
# avaible availble 0.29598165
# avaible availiable 0.3233832
# avaible avaiable 0.32916415
#
# availabe availabe -2.3841858e-07
# availabe avaliable 0.2955308
# availabe availible 0.30267215
# availabe avilable 0.3047917
# availabe availiable 0.32122982
# availabe avalible 0.32164288
# availabe availble 0.32899052
# availabe avaible 0.3534978
#
# availble availble 8.34465e-07
# availble avaliable 0.23955029
# availble avilable 0.2722721
# availble avalible 0.2772225
# availble availible 0.27784503
# availble avaible 0.29598165
# availble availalbe 0.30401742
# availble availiable 0.32707018
#
# availiable availiable -3.5762787e-07
# availiable avalible 0.2957859
# availiable availible 0.30149758
# availiable avaliable 0.3130554
# availiable availabe 0.32122982
# availiable avaible 0.3233832
# availiable avilable 0.32402593
# availiable availble 0.32707018
#
# availible availible 0.0
# availible avaliable 0.22755188
# availible avalible 0.25904202
# availible availble 0.27784503
# availible avaible 0.28141564
# availible avilable 0.29789042
# availible availiable 0.30149758
# availible availabe 0.30267215
#
# avaliable avaliable -1.1920929e-07
# avaliable availible 0.22755188
# avaliable availble 0.23955029
# avaliable avilable 0.2546717
# avaliable avalible 0.25492835
# avaliable avaible 0.27691287
# avaliable availabe 0.2955308
# avaliable avaiable 0.30059826
#
# avalible avalible 4.7683716e-07
# avalible avaible 0.23999822
# avalible avaliable 0.25492835
# avalible availible 0.25904202
# avalible avilable 0.27287638
# avalible availble 0.2772225
# avalible availiable 0.2957859
# avalible availabe 0.32164288
#
# avilable avilable 1.1920929e-07
# avilable avaliable 0.2546717
# avilable avaible 0.2690388
# avilable availble 0.2722721
# avilable avalible 0.27287638
# avilable availible 0.29789042
# avilable availalbe 0.29956853
# avilable availabe 0.3047917
#
# availiability 2000lsi 0.7550167
# availiability 1995apple 0.76884437
# availiability 1995xerox 0.77512974
# availiability 1995national 0.7807868
# availiability 2004lucent 0.7822119
# availiability bankmethod 0.7825034
# availiability licensingmethod 0.7841922
# availiability 2001compaq 0.7843739
#
# availabiltiy avaliability 0.49212462
# availabiltiy availabiliy 0.5087991
# availabiltiy availbility 0.51789045
# availabiltiy availibilty 0.5250197
# availabiltiy availabity 0.5255438
# availabiltiy avalibility 0.5261156
# availabiltiy avaibility 0.53678113
# availabiltiy availiblity 0.5391713
#
# availabilty availabilty 2.9802322e-07
# availabilty availablity 0.42780006
# availabilty availablility 0.5207506
# availabilty gigbuilder 0.5343939
# availabilty availibility 0.5940793
# availabilty availabilities 0.6039375
# availabilty availbility 0.62303257
# availabilty booking 0.62515783
#
# availablility availablility -2.3841858e-07
# availablility availablity 0.44822758
# availablility availibilty 0.5144172
# availablility availablilty 0.5185828
# availablility availabilty 0.5207506
# availablility availbility 0.5215461
# availablility avaliability 0.52848256
# availablility availibility 0.5848572
#
# availablity availablity -4.7683716e-07
# availablity availabilty 0.42780006
# availablity availablility 0.44822758
# availablity availibility 0.5053892
# availablity availbility 0.5645367
# availablity availabilities 0.5808244
# availablity availibilty 0.5839417
# availablity availability 0.5895928
#
# availibility availibility 0.0
# availibility availablity 0.5053892
# availibility availablility 0.5848572
# availibility availabilty 0.5940793
# availibility availability 0.64530087
# availibility availbility 0.65376115
# availibility avaliability 0.6786548
# availibility 06/11/2013pestimated 0.68879235
#
# avaliability avaliability 4.172325e-07
# avaliability availibilty 0.43702304
# avaliability availablilty 0.4857601
# avaliability avalibility 0.48735034
# avaliability availbility 0.49361205
# avaliability availabiliy 0.50878054
# avaliability avaiability 0.5250317
# avaliability availablility 0.52848256
#
# avalibility avalibility -2.3841858e-07
# avalibility availibilty 0.43118775
# avalibility availbility 0.48110318
# avalibility avaliability 0.48735034
# avalibility availabiliy 0.49140728
# avalibility avilability 0.5133155
# avalibility availablilty 0.5283992
# avalibility avaiability 0.55597806
#
# activies activies 3.5762787e-07
# activies activites 0.3138193
# activies activties 0.42396855
# activies actvities 0.4755261
# activies acitivities 0.4904104
# activies extracurricular 0.5170639
# activies extra-curricular 0.51836026
# activies acivities 0.5295122
#
# activites activites 5.9604645e-08
# activites activies 0.3138193
# activites activities 0.34940386
# activites extracurricular 0.42272884
# activites extra-curricular 0.44239968
# activites outings 0.47775018
# activites activties 0.49464917
# activites actvities 0.5053678
#
# actualy actualy -1.1920929e-07
# actualy acutally 0.15356952
# actualy acually 0.15481794
# actualy actaully 0.17952794
# actualy acctually 0.19590855
# actualy actully 0.22169244
# actualy jsut 0.24197435
# actualy allready 0.29310173
#
# acutally acutally 5.9604645e-08
# acutally actaully 0.13266504
# acutally actualy 0.15356952
# acutally acually 0.15364993
# acutally acctually 0.16092753
# acutally actully 0.24963325
# acutally actally 0.28427207
# acutally accually 0.31432563
#
# ammenities ammenities 3.5762787e-07
# ammenities amenties 0.25546753
# ammenities ameneties 0.3148263
# ammenities amenities 0.39109462
# ammenities ammenties 0.42026633
# ammenities amenites 0.43556368
# ammenities amentities 0.4414553
# ammenities amenitites 0.4526224
#
# antoher antoher 4.7683716e-07
# antoher anouther 0.33181578
# antoher anothe 0.3897903
# antoher anothr 0.39885533
# antoher annother 0.41686702
# antoher anotehr 0.42062163
# antoher anohter 0.45211995
# antoher anoter 0.45357543
#
# aweful aweful -3.5762787e-07
# aweful awfull 0.16275555
# aweful god-awful 0.39005095
# aweful horrid 0.39635885
# aweful unbelieveable 0.42213368
# aweful horible 0.42539668
# aweful godawful 0.4276334
# aweful awful 0.44708997
#
# awfull awfull -2.3841858e-07
# awfull aweful 0.16275555
# awfull awefull 0.40280664
# awfull horible 0.40725505
# awfull god-awful 0.4251145
# awfull terible 0.45225745
# awfull unbelieveable 0.46436858
# awfull discusting 0.4773389
#
# awsome awsome 1.7881393e-07
# awsome awesome 0.22414464
# awsome vid 0.268871
# awsome realy 0.29631352
# awsome !!!!!! 0.3023336
# awsome !!!!! 0.31019074
# awsome !!!!!!! 0.31354564
# awsome dude 0.31660116
#
# beacuse beacuse 0.0
# beacuse becuse 0.14846474
# beacuse becouse 0.15402484
# beacuse becasue 0.15543956
# beacuse beacause 0.16104835
# beacuse becuase 0.19004315
# beacuse becuz 0.19157171
# beacuse bcuz 0.22021389
#
# bearly bearly 3.5762787e-07
# bearly barly 0.4783566
# bearly bareley 0.59936106
# bearly feasibly 0.5995399
# bearly berely 0.62060493
# bearly barelly 0.6207397
# bearly bairly 0.64601654
# bearly acutally 0.6624946
#
# beaurocracy beaurocracy -4.7683716e-07
# beaurocracy beauracracy 0.35488296
# beaurocracy bureacracy 0.46488357
# beaurocracy beurocracy 0.47054052
# beaurocracy burocracy 0.50671977
# beaurocracy red-tape 0.52778363
# beaurocracy beaurocratic 0.531789
# beaurocracy beauracratic 0.54439837
#
# beaurocratic beaurocratic 4.7683716e-07
# beaurocratic beurocratic 0.3919831
# beaurocratic bureacratic 0.41630423
# beaurocratic beauracratic 0.46675396
# beaurocratic beauracracy 0.5067256
# beaurocratic beaurocracy 0.531789
# beaurocratic tapism 0.5501191
# beaurocratic time-eating 0.5502175
#
# becasue becasue 0.0
# becasue becuase 0.09085715
# becasue beacuse 0.15543956
# becasue becuse 0.19779754
# becasue becouse 0.20600724
# becasue beacause 0.21207309
# becasue becuz 0.23197848
# becasue eventhough 0.2531277
#
# becuase becuase 5.9604645e-08
# becuase becasue 0.09085715
# becuase beacuse 0.19004315
# becuase b/c 0.19043529
# becuase becouse 0.2055034
# becuase cuz 0.20694321
# becuase becuz 0.22066534
# becuase infact 0.23172277
#
# becuse becuse -2.3841858e-07
# becuse beacuse 0.14846474
# becuse beacause 0.15245771
# becuse becouse 0.16309083
# becuse becuz 0.19531453
# becuse becasue 0.19779754
# becuse bcuz 0.20050389
# becuse becaue 0.22920054
#
# befor befor 1.1920929e-07
# befor be4 0.35446733
# befor untill 0.36907768
# befor beofre 0.38465607
# befor bfore 0.39028823
# befor b4 0.4051081
# befor stoped 0.4273672
# befor tryed 0.4284715
#
# beggining beggining -3.5762787e-07
# beggining begining 0.16738808
# beggining begginning 0.31308973
# beggining beging 0.4186585
# beggining biggining 0.43156087
# beggining beginging 0.45615697
# beggining beacause 0.46306092
# beggining beacuse 0.47069746
#
# begining begining 0.0
# begining beggining 0.16738808
# begining beginning 0.35388327
# begining untill 0.44397372
# begining ending 0.4693855
# begining cuz 0.47078902
# begining realy 0.47474396
# begining tht 0.4794761
#
# beleive beleive -3.5762787e-07
# beleive belive 0.07102209
# beleive becuase 0.31969333
# beleive wouldnt 0.32249713
# beleive cant 0.34422898
# beleive infact 0.348656
# beleive becasue 0.35528636
# beleive believe 0.36395586
#
# belive belive 5.9604645e-07
# belive beleive 0.07102209
# belive wouldnt 0.2866823
# belive cant 0.28927273
# belive becuase 0.30191863
# belive dont 0.30560356
# belive actualy 0.33034593
# belive remeber 0.3325053
#
# benificial benificial -2.3841858e-07
# benificial benefitial 0.45004404
# benificial benefical 0.47020048
# benificial benifical 0.5088129
# benificial advantagous 0.5406498
# benificial interessting 0.56399727
# benificial interresting 0.571525
# benificial intersting 0.57241565
#
# benifit benifit 0.0
# benifit benfit 0.2807467
# benifit benifits 0.46521127
# benifit beneﬁt 0.472309
# benifit benefitted 0.49376225
# benifit benfits 0.5299205
# benifit bennefit 0.536665
# benifit benifet 0.54254335
#
# buiding buiding -2.3841858e-07
# buiding bulding 0.23793471
# buiding builing 0.3176
# buiding buidling 0.331087
# buiding buliding 0.3564136
# buiding builiding 0.46572763
# buiding builidng 0.48624873
# buiding buildin 0.52232975
#
# buidling buidling -4.7683716e-07
# buidling buiding 0.331087
# buidling bulding 0.3506869
# buidling builing 0.38862032
# buidling buliding 0.4549328
# buidling builiding 0.58172435
# buidling building.the 0.6122414
# buidling buildin 0.6261902
#
# buisness buisness 5.9604645e-07
# buisness bussiness 0.1703527
# buisness buisiness 0.33937252
# buisness busines 0.3528247
# buisness bussines 0.3545819
# buisness busniess 0.36961228
# buisness busness 0.4208079
# buisness buissness 0.44834805
#
# buliding buliding -2.3841858e-07
# buliding buiding 0.3564136
# buliding bulding 0.38971686
# buliding builing 0.39552158
# buliding buidling 0.4549328
# buliding builiding 0.57806385
# buliding building.the 0.57995296
# buliding builidng 0.58135617
#
# bureacracy bureacracy 1.1920929e-07
# bureacracy beauracracy 0.40684342
# bureacracy bureaucracy 0.43273336
# bureacracy bureaucracies 0.43503648
# bureacracy beaurocracy 0.46488357
# bureacracy beurocracy 0.5117003
# bureacracy over-regulation 0.51765424
# bureacracy bureacratic 0.5231446
#
# buritto 04.03.00 0.65269953
# buritto hole.mp3 0.6708578
# buritto bed.mp3 0.6712616
# buritto border='0' 0.6717098
# buritto 04.03.01 0.67474854
# buritto prayercentral.net 0.6823132
# buritto raceboats 0.68524253
# buritto tuuune 0.6853125
#
# bussiness bussiness 1.7881393e-07
# bussiness buisness 0.1703527
# bussiness busines 0.28027135
# bussiness bussines 0.28982317
# bussiness buisiness 0.36235142
# bussiness busniess 0.36942285
# bussiness busness 0.3781172
# bussiness businness 0.43702352
#
# calender calender -1.1920929e-07
# calender calander 0.26736826
# calender calendar 0.27320284
# calender calendars 0.34758765
# calender calandar 0.39690197
# calender calenders 0.41724837
# calender ical 0.5651907
# calender dates 0.5784857
#
# casher mulo 0.7477366
# casher nickolas 0.77133834
# casher heatherington 0.77699554
# casher bocado 0.7787093
# casher zunino 0.77944255
# casher terno 0.78114474
# casher karly 0.7822629
# casher mcalarney 0.7884987
#
# catagories catagories 0.0
# catagories sub-categories 0.4001534
# catagories catergories 0.4544599
# catagories catagory 0.51040876
# catagories subcategories 0.51265025
# catagories categories 0.51791143
# catagories catergory 0.5639632
# catagories catogories 0.5780953
#
# catagory catagory -5.9604645e-07
# catagory catergory 0.49665284
# catagory catagories 0.51040876
# catagory category 0.5506586
# catagory sub-categories 0.5981871
# catagory categories 0.5986037
# catagory subcategories 0.60159117
# catagory shoe 0.6214602
#
# cheeper cheeper 0.0
# cheeper cheepest 0.515607
# cheeper afordable 0.52126974
# cheeper costlier 0.5426405
# cheeper meriland 0.5557345
# cheeper applicarions 0.5628552
# cheeper tastier 0.58768517
# cheeper mroe 0.58770686
#
# classs wounderfull 0.6970966
# classs abilitys 0.70006734
# classs beat-em-ups 0.7025692
# classs launguage 0.72720575
# classs contition 0.72906446
# classs combonation 0.73181856
# classs fuctions 0.7363979
# classs guitaring 0.73729175
#
# classses classses 1.1920929e-07
# classses classess 0.54778266
# classses clasess 0.59394056
# classses speccs 0.63021034
# classses calsses 0.6304991
# classses classes.the 0.6325736
# classses laguages 0.63316405
# classses 100-level 0.64367425
#
# cleaniness cleaniness 5.9604645e-07
# cleaniness cleaness 0.4499532
# cleaniness cleanliness 0.55230093
# cleaniness cleanness 0.55880946
# cleaniness tgreat 0.5674723
# cleaniness quiet.the 0.5712949
# cleaniness satff 0.5733323
# cleaniness cleanlines 0.5762419
#
# cofee cofee 0.0
# cofee coffe 0.2604944
# cofee coffeee 0.46505904
# cofee cappucino 0.5390741
# cofee coffie 0.543787
# cofee coffee 0.570897
# cofee cofffee 0.58323264
# cofee cappuccino 0.5927229
#
# coffe coffe 1.1920929e-07
# coffe cofee 0.2604944
# coffe coffee 0.33208662
# coffe cappucino 0.3968076
# coffe cappuccino 0.41179925
# coffe espresso 0.41953325
# coffe coffeee 0.43795103
# coffe latte 0.47297442
#
# collegue collegue 0.0
# collegue ex-colleague 0.42452472
# collegue colleage 0.48953754
# collegue collegues 0.5178566
# collegue freind 0.53171396
# collegue schoolmate 0.5323679
# collegue ex-friend 0.5352434
# collegue ex-boss 0.5586875
#
# coment coment -3.5762787e-07
# coment commet 0.3932122
# coment coments 0.45638925
# coment suscribe 0.5087554
# coment subcribe 0.5448234
# coment plzz 0.5538671
# coment plz 0.56695116
# coment commets 0.5689703
#
# coments coments -3.5762787e-07
# coments commets 0.41067088
# coments coment 0.45638925
# coments replys 0.49600267
# coments commments 0.5087079
# coments commnets 0.51297516
# coments commentors 0.54964095
# coments responces 0.55754673
#
# comming comming 6.556511e-07
# comming comeing 0.2534322
# comming comin 0.37412995
# comming coming 0.38209563
# comming commin 0.47904742
# comming goin 0.48049974
# comming anyways 0.4957838
# comming befor 0.49830586
#
# committment committment 0.0
# committment commitment 0.31763995
# committment comittment 0.3467908
# committment dedication 0.39023888
# committment unwavering 0.43252665
# committment unswerving 0.48444676
# committment professionalism 0.5036514
# committment committments 0.51478714
#
# commment commment 0.0
# commment cooment 0.569657
# commment coment 0.5804728
# commment commet 0.60693365
# commment coments 0.61280644
# commment commets 0.6376943
# commment siggy 0.65446454
# commment commnet 0.6570446
#
# commuication commuication 1.1920929e-07
# commuication communcation 0.45355922
# commuication communiation 0.49654603
# commuication communiction 0.50757754
# commuication commucation 0.53986907
# commuication comunication 0.5494688
# commuication diaglogue 0.5593544
# commuication repore 0.5667188
#
# communter järgmine 0.5930375
# communter leningradskoe 0.6008923
# communter medit8ionsoc 0.6259375
# communter sljedeća 0.63006777
# communter 356/1 0.6362099
# communter pharmalittle 0.6374378
# communter oversikten 0.64220005
# communter punishme 0.6591851
#
# comotion comotion 3.5762787e-07
# comotion fuzion 0.68857974
# comotion rucus 0.6984465
# comotion hoohaa 0.6996252
# comotion voluptuousness 0.7149191
# comotion bruited 0.7192243
# comotion noised 0.72777116
# comotion commotion 0.7327529
#
# comparision comparision -2.3841858e-07
# comparision comparsion 0.28057116
# comparision comparrison 0.33377546
# comparision comparisson 0.42130625
# comparision comparasion 0.50025016
# comparision comparison 0.51116884
# comparision comparisons 0.52766263
# comparision comparisions 0.53670377
#
# compatability compatability -1.1920929e-07
# compatability compatibility 0.25157243
# compatability compatibilty 0.36830634
# compatability compatable 0.42521966
# compatability compatiblity 0.44896138
# compatability incompatibility 0.4886638
# compatability compability 0.5182591
# compatability compatibilities 0.53086215
#
# compatable compatable -2.3841858e-07
# compatable compatiable 0.35565203
# compatable compatible 0.39269692
# compatable compatability 0.42521966
# compatable compatibility 0.51012963
# compatable backwards-compatible 0.5542185
# compatable backward-compatible 0.5635599
# compatable upgradeable 0.58643734
#
# competative competative 1.1920929e-07
# competative competetive 0.11851293
# competative competitve 0.1756897
# competative competive 0.17786181
# competative competitive 0.45237923
# competative resonable 0.5129019
# competative competitively 0.51454145
# competative cut-throat 0.51509476
#
# competetive competetive 1.7881393e-07
# competetive competative 0.11851293
# competetive competitve 0.16228294
# competetive competive 0.17993402
# competetive competitive 0.41616786
# competetive cut-throat 0.44648957
# competetive competitively 0.48608547
# competetive petitive 0.5390973
#
# competive competive 1.7881393e-07
# competive competative 0.17786181
# competive competetive 0.17993402
# competive competitve 0.19187689
# competive competitive 0.50915563
# competive cut-throat 0.5169424
# competive compeitive 0.5409366
# competive comptitive 0.54201543
#
# completly completly 1.1920929e-07
# completly completley 0.2001921
# completly totaly 0.3233387
# completly completely 0.34221804
# completly totally 0.36760598
# completly competely 0.39581275
# completly completey 0.39865232
# completly compleatly 0.4082104
#
# comraderie comraderie 2.3841858e-07
# comraderie comradery 0.17230207
# comraderie camaraderie 0.2696997
# comraderie cameraderie 0.2982946
# comraderie camraderie 0.32705104
# comraderie comradeship 0.3465479
# comraderie comaraderie 0.3949678
# comraderie comeraderie 0.4366982
#
# comradery comradery 1.1920929e-07
# comradery comraderie 0.17230207
# comradery camaraderie 0.27239215
# comradery comradeship 0.33609146
# comradery cameraderie 0.36411148
# comradery camraderie 0.3689953
# comradery comaraderie 0.38346666
# comradery cohesiveness 0.46633935
#
# comunication comunication 1.7881393e-07
# comunication communcation 0.45746452
# comunication commuication 0.5494688
# comunication inter-personal 0.56977284
# comunication comunications 0.59530675
# comunication communciation 0.60237837
# comunication colaboration 0.6040643
# comunication conection 0.60594016
#
# comunity comunity 3.5762787e-07
# comunity communty 0.41697812
# comunity communtiy 0.4182921
# comunity munity 0.5047056
# comunity commnity 0.539424
# comunity community 0.54347414
# comunity commmunity 0.5608494
# comunity communitiy 0.582933
#
# concious concious 1.1920929e-07
# concious consious 0.26845098
# concious conscious 0.3697908
# concious self-conscious 0.50772166
# concious sub-conscious 0.5232974
# concious subconcious 0.5516217
# concious self-aware 0.5543405
# concious unconcious 0.57977706
#
# condusive condusive 5.9604645e-07
# condusive conducive 0.5365
# condusive mountainy 0.60918677
# condusive bucolic 0.6226846
# condusive foot-in-the 0.6237347
# condusive congenial 0.650121
# condusive untypical 0.6841922
# condusive unobscured 0.6865373
#
# conection conection -1.1920929e-07
# conection connetion 0.35035753
# conection connnection 0.4262209
# conection connction 0.44244355
# conection connecton 0.46007824
# conection conections 0.48346424
# conection connecion 0.51721823
# conection conneciton 0.5348199
#
# confortable confortable -2.3841858e-07
# confortable comfotable 0.3443333
# confortable comforable 0.35738927
# confortable comfortable 0.39289832
# confortable comfy 0.42873913
# confortable spotlessly 0.45495588
# confortable cosy 0.46115863
# confortable comfortabel 0.4736638
#
# consistant consistant 0.0
# consistant consistent 0.39108193
# consistant consistantly 0.4170581
# consistant acurate 0.49231464
# consistant repeatable 0.51043254
# consistant inconsistant 0.5155181
# consistant consitent 0.518486
# consistant steady 0.5337424
#
# consistantly consistantly 1.1920929e-07
# consistantly consistenly 0.19543433
# consistantly consistently 0.3489464
# consistantly dependably 0.39337093
# consistantly consistant 0.4170581
# consistantly consitently 0.43079102
# consistantly reliably 0.43305808
# consistantly continously 0.49479008
#
# consistenly consistenly -2.3841858e-07
# consistenly consistantly 0.19543433
# consistenly consitently 0.3458351
# consistenly dependably 0.44480836
# consistenly consisently 0.45296478
# consistenly consitantly 0.45622838
# consistenly continuosly 0.4963017
# consistenly consistently 0.50633216
#
# continously continously -2.3841858e-07
# continously continuosly 0.24611133
# continously continuously 0.4039613
# continously continiously 0.42438596
# continously continually 0.47090524
# continously intermittently 0.47451305
# continously unceasingly 0.490319
# continously consistantly 0.49479008
#
# contruction contruction 5.9604645e-08
# contruction constuction 0.3610676
# contruction consruction 0.4315071
# contruction constrution 0.44004226
# contruction constructon 0.49535787
# contruction costruction 0.50049967
# contruction consturction 0.51136976
# contruction construction 0.5209787
#
# conveinent conveinent 1.1920929e-07
# conveinent convienent 0.4111033
# conveinent conveient 0.42463326
# conveinent convienant 0.44673955
# conveinent convienient 0.4569525
# conveinent convinient 0.46137494
# conveinent convient 0.4747702
# conveinent conventient 0.48623562
#
# conveinient conveinient 2.3841858e-07
# conveinient convienant 0.35428506
# conveinient conventient 0.37612772
# conveinient convinent 0.41007924
# conveinient conveient 0.41916877
# conveinient convienient 0.42085367
# conveinient convienent 0.42435694
# conveinient convinient 0.43465495
#
# conveniant conveniant -4.7683716e-07
# conveniant convienent 0.40921813
# conveniant convinient 0.4227537
# conveniant convient 0.43298626
# conveniant conveient 0.44435716
# conveniant conveinient 0.4524812
# conveniant convienient 0.45310557
# conveniant convienant 0.45532274
#
# conveniece conveniece 0.0
# conveniece convienance 0.44686007
# conveniece convienience 0.47011602
# conveniece convienence 0.4807331
# conveniece convenince 0.4900353
# conveniece conveinence 0.50892735
# conveniece conveience 0.51627004
# conveniece covenience 0.54168606
#
# conveninent mood-lifter 0.56716913
# conveninent tone-setter 0.6001279
# conveninent alsoavailable 0.6066228
# conveninent ехсеllеnt 0.6259668
# conveninent trojan/backdoor 0.626907
# conveninent de-stresser 0.62943625
# conveninent 649-3810 0.62956965
# conveninent 548-1159 0.6296305
#
# convienance border='0' 0.51409936
# convienance crossed-flag-pins 0.54431677
# convienance texasstar7 0.55327344
# convienance 12.05.27 0.5541917
# convienance 12.05.26 0.5570442
# convienance intranet.zip 0.5578119
# convienance fxus61 0.55794203
# convienance naturebeautiful 0.56016785
#
# convienant convienant 1.1920929e-07
# convienant convienient 0.33758473
# convienant convinent 0.34204048
# convienant convienent 0.3493688
# convienant conveinient 0.35428506
# convienant conventient 0.37558937
# convienant convinient 0.38062078
# convienant conveient 0.41786808
#
# convience convience -1.1920929e-07
# convience convienience 0.3484981
# convience convienence 0.35550612
# convience convenince 0.536214
# convience convenience 0.5471373
# convience conveniece 0.5572204
# convience convinience 0.5724253
# convience convinence 0.5757285
#
# convienence convienence 0.0
# convienence convienience 0.31964982
# convienence convience 0.35550612
# convienence convenince 0.47936964
# convienence conveniece 0.4807331
# convienence convienance 0.48962432
# convienence convinence 0.49773043
# convienence conveinence 0.533266
#
# convienent convienent 1.1920929e-07
# convienent convienient 0.19823259
# convienent convient 0.2147516
# convienent convinient 0.23351157
# convienent convienant 0.3493688
# convienent convinent 0.380278
# convienent conveniant 0.40921813
# convienent conveinent 0.4111033
#
# convienience convienience 0.0
# convienience convienence 0.31964982
# convienience convience 0.3484981
# convienience conveniece 0.47011602
# convienience convienance 0.4889521
# convienience conveniance 0.49762994
# convienience convenince 0.5065849
# convienience convinience 0.5284238
#
# convienient convienient -3.5762787e-07
# convienient convienent 0.19823259
# convienient convinient 0.25744903
# convienient convient 0.28958982
# convienient convienant 0.33758473
# convienient convinent 0.3597417
# convienient conveinient 0.42085367
# convienient conveniant 0.45310557
#
# convient convient 0.0
# convient convienent 0.2147516
# convient convienient 0.28958982
# convient convinient 0.31285036
# convient convienant 0.41975504
# convient conveniant 0.43298626
# convient convinent 0.44734746
# convient conveinient 0.47173572
#
# conviently conviently 0.0
# conviently conviniently 0.3333671
# conviently convieniently 0.3750614
# conviently conveniantly 0.4198538
# conviently convienently 0.44507736
# conviently conveinently 0.4584306
# conviently coveniently 0.46670783
# conviently convenietly 0.48500043
#
# convinence convinence 0.0
# convinence conveience 0.45832282
# convinence convenince 0.46402752
# convinence convienence 0.49773043
# convinence convienance 0.5268344
# convinence convienience 0.55510414
# convinence conveinence 0.56108993
# convinence covenience 0.56139576
#
# convinent convinent -1.1920929e-07
# convinent convienant 0.34204048
# convinent convienient 0.3597417
# convinent convienent 0.380278
# convinent convinient 0.38125122
# convinent conveinient 0.41007924
# convinent conveient 0.4183486
# convinent conveniet 0.42272568
#
# convinience convinience 5.364418e-07
# convinience convienience 0.5284238
# convinience convience 0.5724253
# convinience conveniece 0.59842104
# convinience convienence 0.608465
# convinience convenince 0.6389749
# convinience conveience 0.6463994
# convinience convienance 0.6629628
#
# convinient convinient 3.5762787e-07
# convinient convienent 0.23351157
# convinient convienient 0.25744903
# convinient convient 0.31285036
# convinient convienant 0.38062078
# convinient convinent 0.38125122
# convinient conveniant 0.4227537
# convinient conveinient 0.43465495
#
# corteous corteous -3.5762787e-07
# corteous couteous 0.23535168
# corteous courtious 0.2836883
# corteous accommadating 0.3115474
# corteous attentative 0.31614846
# corteous curteous 0.32127678
# corteous accomdating 0.3226512
# corteous acommodating 0.32332778
#
# courtis ihne 0.64191103
# courtis guinigundo 0.65979135
# courtis rubinsohn 0.6713083
# courtis rönnqvist 0.677216
# courtis zaelke 0.6795461
# courtis serwatka 0.68071616
# courtis aggieceo 0.6845534
# courtis prukop 0.68514174
#
# couteous couteous -1.1920929e-07
# couteous corteous 0.23535168
# couteous courtious 0.29614037
# couteous curteous 0.3166402
# couteous curtious 0.33945274
# couteous friendly/helpful 0.35408598
# couteous attentative 0.36941254
# couteous superfriendly 0.39836758
#
# covenient covenient -2.3841858e-07
# covenient convienent 0.42581314
# covenient convinent 0.43386787
# covenient convinient 0.4442724
# covenient conveinient 0.4628898
# covenient conveniet 0.4661755
# covenient convienient 0.47189432
# covenient convienant 0.4770342
#
# croweded bad.â 0.5325016
# croweded fast.so 0.53870094
# croweded complcated 0.5479245
# croweded complicted 0.54912305
# croweded un-exciting 0.56195045
# croweded ridonkulously 0.56196594
# croweded frustraiting 0.5628159
# croweded godawfully 0.5642158
#
# curteous curteous 1.1920929e-07
# curteous curtious 0.24800903
# curteous courtious 0.25245208
# curteous couteous 0.3166402
# curteous corteous 0.32127678
# curteous attentative 0.41990113
# curteous courteous 0.42264456
# curteous accomdating 0.45787156
#
# curtesy woodlice 0.71580243
# curtesy fix-its 0.7443012
# curtesy co-religionists 0.7556388
# curtesy after-effect 0.7589629
# curtesy persecutors 0.7617789
# curtesy corner-to-corner 0.7685086
# curtesy inchworms 0.7697791
# curtesy spanish-speakers 0.77115333
#
# curtious curtious 1.1920929e-07
# curtious curteous 0.24800903
# curtious courtious 0.2799276
# curtious corteous 0.3315056
# curtious couteous 0.33945274
# curtious courteous 0.45253515
# curtious accomdating 0.47360748
# curtious accomadating 0.47850132
#
# deaprtment deaprtment 0.0
# deaprtment deartment 0.4186952
# deaprtment de-partment 0.4418006
# deaprtment departent 0.46486312
# deaprtment deptment 0.4821658
# deaprtment departmet 0.48910916
# deaprtment departmnet 0.5033513
# deaprtment depatment 0.50865465
#
# decission decission 5.9604645e-07
# decission descision 0.24776888
# decission desicion 0.2689649
# decission decison 0.27760345
# decission decsion 0.3150699
# decission desision 0.35823673
# decission decesion 0.3862911
# decission desicions 0.3928156
#
# definately definately -5.9604645e-07
# definately definetly 0.14961475
# definately definitly 0.1605019
# definately definatly 0.1727665
# definately definitely 0.1775958
# definately definetely 0.2944275
# definately definatley 0.29531145
# definately wouldnt 0.30130142
#
# definetely definetely -2.3841858e-07
# definetely definatley 0.14277625
# definetely definitly 0.14862049
# definetely defintely 0.15026277
# definetely definatly 0.16065836
# definetely definitley 0.16066116
# definetely definetly 0.17626095
# definetely deffinately 0.17821229
#
# definetly definetly -2.3841858e-07
# definetly definitly 0.08354956
# definetly definatly 0.09189063
# definetly definately 0.14961475
# definetly definatley 0.15719211
# definetly definitley 0.16768986
# definetly definetely 0.17626095
# definetly defintely 0.177504
#
# definitley definitley 4.7683716e-07
# definitley definatley 0.11255336
# definitley deffinately 0.12678748
# definitley definitly 0.13280058
# definitley defintely 0.13321304
# definitley definatly 0.14365679
# definitley definetely 0.16066116
# definitley definently 0.16482794
#
# definitly definitly 1.7881393e-07
# definitly definatly 0.048039317
# definitly definetly 0.08354956
# definitly definatley 0.12112445
# definitly definitley 0.13280058
# definitly defintely 0.1475907
# definitly definetely 0.14862049
# definitly definately 0.1605019
#
# delievered delievered 1.1920929e-07
# delievered deliverd 0.47965062
# delievered delevered 0.53160596
# delievered couriered 0.5373626
# delievered shiped 0.5508237
# delievered deliveried 0.5609546
# delievered deliever 0.566061
# delievered delievery 0.5787135
#
# deliverers deliverers 1.7881393e-07
# deliverers deliverer 0.5414327
# deliverers procurers 0.636343
# deliverers hate-mongers 0.6397364
# deliverers evangelizers 0.6520657
# deliverers tormentors 0.6805968
# deliverers disseminators 0.6810025
# deliverers extortionists 0.6820767
#
# deparment deparment -1.1920929e-07
# deparment deptartment 0.31481194
# deparment depatment 0.3351025
# deparment dept. 0.45981222
# deparment departent 0.46932745
# deparment departmet 0.48095548
# deparment dept 0.4859531
# deparment deprtment 0.5140033
#
# deparments deparments 5.364418e-07
# deparments departments.the 0.5691494
# deparments depts 0.57416236
# deparments depts. 0.58615386
# deparments dapartment 0.58787715
# deparments de-partment 0.59396225
# deparments police/sheriff 0.6030569
# deparments work-groups 0.6195233
#
# departement departement 0.0
# departement camping_car 0.49814272
# departement département 0.541832
# departement isere 0.6011701
# departement maritimes 0.6088782
# departement deparment 0.62184465
# departement alpes 0.6229295
# departement ariege 0.6337334
#
# departmet ever-presence 0.643353
# departmet connectionalism 0.66807854
# departmet showcaseyourmusic.com 0.6708944
# departmet fight-flight 0.678764
# departmet toothlessness 0.679801
# departmet quasi-stable 0.6817812
# departmet nature-the 0.6854311
# departmet nature.a 0.6856106
#
# depratment depratment -2.3841858e-07
# depratment departmnet 0.40897667
# depratment deartment 0.43678778
# depratment departent 0.44863427
# depratment deapartment 0.4703915
# depratment oftransportation 0.48069596
# depratment de-partment 0.48790503
# depratment departmetn 0.49060488
#
# deptartment deptartment -5.9604645e-07
# deptartment deparment 0.31481194
# deptartment depatment 0.4384281
# deptartment departmet 0.4818958
# deptartment departent 0.49928337
# deptartment deartment 0.5067828
# deptartment deaprtment 0.51448655
# deptartment deprtment 0.5235765
#
# descrimination descrimination 1.1920929e-07
# descrimination discrimation 0.4546876
# descrimination dicrimination 0.49565762
# descrimination discrmination 0.49893677
# descrimination discrimnation 0.5300668
# descrimination discimination 0.53447515
# descrimination rascism 0.5381682
# descrimination racisim 0.5860109
#
# desireable desireable 0.0
# desireable desirable 0.36965877
# desireable messiest 0.4936508
# desireable blistery 0.5066075
# desireable ravishing 0.5159823
# desireable extremest 0.53178614
# desireable sought-after 0.5474293
# desireable steamiest 0.54810095
#
# differnt differnt 5.364418e-07
# differnt diffrent 0.09014225
# differnt differant 0.11967641
# differnt diferent 0.12722307
# differnt differnet 0.18192387
# differnt diffent 0.25102198
# differnt diffferent 0.2738217
# differnt differents 0.30525577
#
# diffrent diffrent -1.1920929e-07
# diffrent differnt 0.09014225
# diffrent diferent 0.12840414
# diffrent differant 0.13980818
# diffrent differnet 0.2322911
# diffrent diffent 0.28966594
# diffrent diffferent 0.33446944
# diffrent difrent 0.34322035
#
# dinig dinig 3.5762787e-07
# dinig dinnig 0.49049294
# dinig kitchen/dinning 0.5100163
# ...
# supples laryngol 0.7769661
#
# suppossed suppossed 5.9604645e-08
# suppossed suposed 0.23227286
# suppossed supossed 0.27644557
# suppossed suppost 0.301785
# suppossed susposed 0.3581649
# suppossed sopposed 0.36154306
# suppossed suppposed 0.3792131
# suppossed supose 0.3821923
#
# suprised suprised -2.3841858e-07
# suprised dissapointed 0.22131091
# suprised surprized 0.23544848
# suprised surprised 0.2838143
# suprised surpised 0.2923652
# suprised dissappointed 0.32429636
# suprised supprised 0.33106375
# suprised shocked 0.33381712
#
# suvey showcaseyourmusic.com 0.6042599
# suvey 04.04.29 0.6087258
# suvey colliction 0.6098695
# suvey 05/30/89 0.6120305
# suvey 05/08/90 0.61744416
# suvey 08/16/94 0.6174847
# suvey crossed-flag-pins 0.6189527
# suvey 06/12/90 0.62260866
#
# sytem sytem 1.1920929e-07
# sytem system.the 0.39546084
# sytem sytems 0.45149648
# sytem sysem 0.4856326
# sytem system 0.51226944
# sytem sysytem 0.5286298
# sytem systemthe 0.5361029
# sytem systme 0.5556851
#
# thats thats -2.3841858e-07
# thats isnt 0.13961834
# thats lol 0.16459388
# thats cuz 0.18313605
# thats theres 0.18671381
# thats yeah 0.18922001
# thats damn 0.19500238
# thats whats 0.20510459
#
# theives theives -2.3841858e-07
# theives thiefs 0.31979692
# theives thieves 0.32310963
# theives robbers 0.5102885
# theives muggers 0.5228156
# theives scumbags 0.522967
# theives rapists 0.53149974
# theives conmen 0.53896445
#
# thiefs thiefs 5.9604645e-08
# thiefs theives 0.31979692
# thiefs muggers 0.5098767
# thiefs thieves 0.5158829
# thiefs conmen 0.51969147
# thiefs robbers 0.54739237
# thiefs rapists 0.57052445
# thiefs druggies 0.57166064
#
# threating threating 5.9604645e-08
# threating threatning 0.2870499
# threating threathening 0.4672401
# threating threatining 0.5018049
# threating theatening 0.518018
# threating harrassing 0.53066206
# threating treatening 0.56652933
# threating threatening 0.5890846
#
# throughly throughly 5.9604645e-08
# throughly thouroughly 0.22625118
# throughly thorougly 0.29791307
# throughly thoroughly 0.3235771
# throughly throroughly 0.37567627
# throughly thoughly 0.4168353
# throughly thuroughly 0.4221639
# throughly thouroghly 0.43503678
#
# throught throught -2.3841858e-07
# throught thorugh 0.31198204
# throught thro 0.36194694
# throught throgh 0.37222832
# throught thru 0.39166975
# throught throug 0.40382642
# throught throuh 0.4372821
# throught thoughout 0.45667797
#
# throughtout throughtout 1.1920929e-07
# throughtout througout 0.17530978
# throughtout thoughout 0.1753884
# throughtout through-out 0.20073605
# throughtout troughout 0.3544827
# throughtout thruout 0.36385858
# throughtout thorughout 0.42929673
# throughtout throuhout 0.4544512
#
# traing traing -1.1920929e-07
# traing traning 0.36497986
# traing trainig 0.39142758
# traing trianing 0.4475996
# traing trainging 0.48835963
# traing traiing 0.52080256
# traing trainng 0.5379032
# traing trainning 0.5580157
#
# trainning trainning -2.3841858e-07
# trainning traning 0.4009148
# trainning trainig 0.4687621
# trainning traing 0.5580157
# trainning trainin 0.61559343
# trainning trianing 0.62297326
# trainning trainng 0.6230501
# trainning trainiing 0.623376
#
# tranfers tranfers -2.3841858e-07
# tranfers tranfer 0.5172734
# tranfers trasfer 0.5285277
# tranfers transfering 0.5901466
# tranfers transfered 0.5968754
# tranfers transfers 0.6009857
# tranfers transfe 0.60267866
# tranfers trasnfer 0.60806674
#
# transfered transfered 1.1920929e-07
# transfered transferred 0.3242767
# transfered transfering 0.36169922
# transfered tranferred 0.413495
# transfered tranfer 0.42903036
# transfered transferring 0.50269103
# transfered tranfered 0.5332262
# transfered copied 0.5396918
#
# transfering transfering 0.0
# transfering transferring 0.27084428
# transfering transfered 0.36169922
# transfering tranfer 0.4019788
# transfering tranferring 0.45070785
# transfering ftping 0.51195407
# transfering tranferred 0.5360751
# transfering retreiving 0.549666
#
# transporation transporation 4.7683716e-07
# transporation transportaion 0.46508384
# transporation transportion 0.530427
# transporation tranportation 0.5317182
# transporation transportation 0.55884254
# transporation transportations 0.5738214
# transporation 2009-02-03 0.58420515
# transporation fb2 0.5860152
#
# transportaion transportaion -4.7683716e-07
# transportaion transporation 0.46508384
# transportaion transportion 0.47476202
# transportaion transportations 0.5007925
# transportaion trasportation 0.5219164
# transportaion tranportation 0.5309796
# transportaion tranport 0.56440365
# transportaion transpotation 0.5786066
#
# transportations transportations 4.7683716e-07
# transportations transportaion 0.5007925
# transportations transportion 0.5495956
# transportations transporation 0.5738214
# transportations tranport 0.6069004
# transportations trasportation 0.61371243
# transportations transportation 0.62132025
# transportations seaports 0.632458
#
# transportion org.w3c.dom.node 0.7394074
# transportion java.sql.preparedstatement 0.74238575
# transportion xaresource 0.74648863
# transportion java.sql.statement 0.7524676
# transportion windowclosing 0.7556368
# transportion java.io.inputstream 0.757783
# transportion pagereference 0.75965285
# transportion icollectionview 0.762689
#
# tremedously tremedously 2.3841858e-07
# tremedously immensley 0.3984627
# tremedously immensly 0.4009959
# tremedously immeasureably 0.48737764
# tremedously imensely 0.5051763
# tremedously enourmously 0.50624466
# tremedously drammatically 0.52003473
# tremedously dramitically 0.52925223
#
# tshirt tshirt -4.7683716e-07
# tshirt t-shirt 0.15403223
# tshirt shirt 0.23928374
# tshirt hoodie 0.2675358
# tshirt t-shirts 0.2720095
# tshirt shirts 0.29272932
# tshirt sweatshirt 0.29405868
# tshirt tee 0.33533645
#
# tshirts tshirts 3.5762787e-07
# tshirts t-shirts 0.26218885
# tshirts shirts 0.32330954
# tshirts tshirt 0.34481514
# tshirts hoodies 0.37387276
# tshirts sweatshirts 0.40732908
# tshirts t-shirt 0.41701782
# tshirts tees 0.42631394
#
# tution tution -1.1920929e-07
# tution tuitions 0.47741324
# tution tuition 0.516865
# tution tutions 0.54091597
# tution tuiton 0.541536
# tution maths 0.59089565
# tution tutoring 0.60296607
# tution tutition 0.6141963
#
# tutition 00:58:29 0.71940863
# tutition 00:30:24 0.724401
# tutition pinkibus 0.73553246
# tutition 00:53:54 0.7409589
# tutition 00:39:13 0.74329895
# tutition 00:59:39 0.74571633
# tutition 15:54:17 0.7468814
# tutition 00:32:39 0.7483258
#
# unaccessible unaccessible -1.1920929e-07
# unaccessible unuseable 0.5443642
# unaccessible unaccessable 0.5557517
# unaccessible inaccessable 0.5561898
# unaccessible inaccessible 0.5654284
# unaccessible un-useable 0.5697553
# unaccessible inaccesible 0.5790468
# unaccessible unusable 0.58461815
#
# unconvenient unconvenient 1.1920929e-07
# unconvenient inconvinient 0.4379841
# unconvenient incovenient 0.43844295
# unconvenient inconvienient 0.459144
# unconvenient diffuclt 0.46497494
# unconvenient diffficult 0.48484343
# unconvenient un-republican 0.48556942
# unconvenient diffiicult 0.48682106
#
# unecessary unecessary 1.7881393e-07
# unecessary unneccessary 0.16425157
# unecessary unneccesary 0.23056924
# unecessary un-necessary 0.26223397
# unecessary unnecesary 0.33749998
# unecessary unnecessary 0.3436551
# unecessary un-needed 0.35198396
# unecessary unneeded 0.3735808
#
# unflexible unflexible -5.9604645e-07
# unflexible inefficent 0.53219926
# unflexible short-sited 0.5337926
# unflexible stubbon 0.5416677
# unflexible inneficient 0.5565417
# unflexible hipocritical 0.55747086
# unflexible unefficient 0.57189214
# unflexible over-complex 0.5734102
#
# unforseen unforseen -1.1920929e-07
# unforseen unforeseen 0.17186236
# unforseen unforeseeable 0.27662802
# unforseen unanticipated 0.31057787
# unforseen unpredicted 0.36862463
# unforseen extenuating 0.40532327
# unforseen unforseeable 0.4343865
# unforseen untoward 0.44083846
#
# univerisity univerisity 3.5762787e-07
# univerisity univerity 0.37167728
# univerisity univeristy 0.41595864
# univerisity unviersity 0.4194283
# univerisity universtiy 0.42706895
# univerisity unversity 0.44768292
# univerisity universiy 0.4823693
# univerisity univesity 0.48383147
#
# univeristy univeristy 0.0
# univeristy unversity 0.32644755
# univeristy univerity 0.34039438
# univeristy unviersity 0.40343523
# univeristy univesity 0.40605193
# univeristy univ. 0.4134642
# univeristy univerisity 0.41595864
# univeristy universtiy 0.41656756
#
# univerity univerity -1.1920929e-07
# univerity univeristy 0.34039438
# univerity unversity 0.354029
# univerity unviersity 0.37001282
# univerity univerisity 0.37167728
# univerity universtiy 0.39369416
# univerity univesity 0.44051528
# univerity universtity 0.44173968
#
# unknowledgeable unknowledgeable 1.1920929e-07
# unknowledgeable unknowledgable 0.4658481
# unknowledgeable ill-educated 0.48626685
# unknowledgeable under-informed 0.51526946
# unknowledgeable undereducated 0.5180254
# unknowledgeable under-educated 0.52069795
# unknowledgeable ill-informed 0.526215
# unknowledgeable uninformed 0.5421425
#
# unneccessary unneccessary -2.3841858e-07
# unneccessary unecessary 0.16425157
# unneccessary unneccesary 0.23049235
# unneccessary un-necessary 0.25670117
# unneccessary unnecesary 0.28049332
# unneccessary un-needed 0.32707262
# unneccessary uneccessary 0.3351977
# unneccessary unncessary 0.3554626
#
# unrealiable unrealiable 2.3841858e-07
# unrealiable un-reliable 0.47735244
# unrealiable inacurrate 0.5308132
# unrealiable extremenly 0.53182054
# unrealiable incredibally 0.53584135
# unrealiable idoitic 0.5360278
# unrealiable incredebly 0.53652024
# unrealiable incomptent 0.5381913
#
# untill untill 0.0
# untill till 0.19130045
# untill until 0.29078698
# untill til 0.30056787
# untill befor 0.36907768
# untill atleast 0.3719923
# untill wont 0.385809
# untill 'till 0.38748723
#
# unversity unversity -2.3841858e-07
# unversity univeristy 0.32644755
# unversity univerity 0.354029
# unversity universtiy 0.374206
# unversity unviersity 0.3783232
# unversity univesity 0.42816317
# unversity univerisity 0.44768292
# unversity universty 0.4670683
#
# useability useability 0.0
# useability user-friendliness 0.42942774
# useability usability 0.4547267
# useability navigability 0.51920366
# useability maintainability 0.54212976
# useability ease-of-use 0.54573333
# useability operability 0.5465753
# useability usabilty 0.5625328
#
# usefull usefull 4.7683716e-07
# usefull useful 0.3839571
# usefull helpfull 0.3862412
# usefull intersting 0.3961863
# usefull intresting 0.3992511
# usefull usful 0.4727552
# usefull helpful 0.48410815
# usefull realy 0.49049747
#
# ususally ususally 0.0
# ususally usally 0.20238
# ususally usualy 0.21850449
# ususally usaully 0.30539024
# ususally normaly 0.38809925
# ususally generaly 0.39805984
# ususally acutally 0.40918243
# ususally useally 0.41316342
#
# vaccum vaccum 4.7683716e-07
# vaccum vaccuum 0.17411184
# vaccum vacum 0.19660014
# vaccum vacume 0.28449285
# vaccum vacuum 0.3268578
# vaccum vacumn 0.33831418
# vaccum vaccume 0.4381581
# vaccum vacumm 0.48951757
#
# vaccuum vaccuum -3.5762787e-07
# vaccuum vaccum 0.17411184
# vaccuum vacum 0.24825633
# vaccuum vacume 0.30550736
# vaccuum vacumn 0.3116871
# vaccuum vaccume 0.4199363
# vaccuum vacuum 0.42902446
# vaccuum vacumm 0.46391743
#
# vaction vaction 1.1920929e-07
# vaction vacaton 0.4074332
# vaction vacay 0.4429404
# vaction vacaion 0.47770286
# vaction stay-cation 0.50658953
# vaction vacation 0.520403
# vaction staycation 0.52761424
# vaction vaccation 0.53685
#
# vacume vacume 0.0
# vacume vaccum 0.28449285
# vacume vacum 0.30021054
# vacume vaccuum 0.30550736
# vacume vacumn 0.35885793
# vacume vaccume 0.47739762
# vacume vacuum 0.55049324
# vacume vacumm 0.5520204
#
# variaty variaty -2.3841858e-07
# variaty varitey 0.43673104
# variaty veriety 0.46151102
# variaty varity 0.4824376
# variaty vaiety 0.50166655
# variaty veriaty 0.5276337
# variaty vairety 0.52939755
# variaty vareity 0.5439248
#
# varities varities 4.7683716e-07
# varities varity 0.5151583
# varities varieties 0.5242662
# varities diffent 0.53445095
# varities vareity 0.54770815
# varities differnt 0.56351155
# varities differnet 0.5706985
# varities differents 0.5724919
#
# varity varity -4.7683716e-07
# varity veriety 0.45651388
# varity varitey 0.45762134
# varity vareity 0.47734678
# varity variaty 0.4824376
# varity varities 0.5151583
# varity varietyof 0.51522225
# varity veriaty 0.54687256
#
# vegeterian vegeterian 0.0
# vegeterian vegatarian 0.44691247
# vegeterian vegitarian 0.45031667
# vegeterian vegan/vegetarian 0.50070405
# vegeterian non-vegetarian 0.5624528
# vegeterian vegetarian 0.5717627
# vegeterian macrobiotic 0.58854413
# vegeterian raw-food 0.595696
#
# vegitarian vegitarian -1.1920929e-07
# vegitarian vegatarian 0.4370545
# vegitarian vegeterian 0.45031667
# vegitarian vegan/vegetarian 0.53725255
# vegitarian vegetarian 0.5400439
# vegitarian raw-food 0.5682488
# vegitarian vegan 0.5727328
# vegitarian meat-free 0.578809
#
# vegitarians vegitarians 0.0
# vegitarians pescatarians 0.42413086
# vegitarians vegeterians 0.4485985
# vegitarians vegans/vegetarians 0.47455168
# vegitarians vegetarians/vegans 0.4839989
# vegitarians pescetarians 0.49136615
# vegitarians pot-heads 0.51878226
# vegitarians fooders 0.5247174
#
# vegtables vegtables 1.1920929e-07
# vegtables vegatables 0.41002977
# vegtables vegies 0.42297024
# vegtables veges 0.5303425
# vegtables vegis 0.53190815
# vegtables vegs 0.5507535
# vegtables vegitables 0.5543098
# vegtables fruits 0.56279004
#
# ventillation ventillation -1.1920929e-07
# ventillation ventalation 0.44680178
# ventillation ventilating 0.56446326
# ventillation ventialtion 0.5809629
# ventillation ventilation 0.5934512
# ventillation cross-ventilation 0.6285793
# ventillation ventilations 0.6289271
# ventillation air-flow 0.63716745
#
# veriety veriety 3.5762787e-07
# veriety varity 0.45651388
# veriety variaty 0.46151102
# veriety vareity 0.46515262
# veriety veriaty 0.46736473
# veriety varitey 0.47246528
# veriety varety 0.47307646
# veriety vairety 0.50440454
#
# visted visted 1.1920929e-07
# visted vacationed 0.49339747
# visted visisted 0.51197696
# visted visitied 0.5123842
# visted visited 0.5350028
# visted skiied 0.5590831
# visted visitng 0.56548935
# visted frequented 0.5703269
#
# vistor accountwarrantyreturn 0.73585993
# vistor growingbuy 0.76143175
# vistor hiringgovernment 0.76245046
# vistor servicelog-in 0.7641751
# vistor blogsdo 0.7726911
# vistor complianceofccp 0.7738928
# vistor phonefollow 0.7775078
# vistor papertrack 0.7794179
#
# vistors vistors 5.9604645e-07
# vistors visiters 0.48309797
# vistors visitors 0.5368521
# vistors out-of-towners 0.576125
# vistors vistor 0.60562634
# vistors uniques 0.60647464
# vistors conventioneers 0.6154164
# vistors visitor 0.6237273
#
# wierd wierd 6.556511e-07
# wierd weird 0.19698232
# wierd werid 0.33724236
# wierd kinda 0.3498981
# wierd strange 0.3670653
# wierd sorta 0.3744551
# wierd freaky 0.39791095
# wierd odd 0.41031832
#
# wirless edwall 0.803551
# wirless carlsborg 0.80637646
# wirless bickleton 0.81284505
# wirless oakesdale 0.813422
# wirless crossnore 0.8147845
# wirless kanopolis 0.8161378
# wirless tsaile 0.81662846
# wirless pansey 0.8170584
#
# withdrawl withdrawl 5.9604645e-07
# withdrawl withdrawal 0.26440275
# withdrawl withdrawls 0.3209709
# withdrawl withdrawel 0.34325993
# withdrawl lexapro 0.3838604
# withdrawl effexor 0.38972962
# withdrawl ultram 0.40383017
# withdrawl xanax 0.40599322
#
# woudl woudl 5.9604645e-08
# woudl woud 0.20888281
# woudl whould 0.23226488
# woudl woul 0.28053993
# woudl shoudl 0.28208888
# woudl shoud 0.31151772
# woudl willl 0.320242
# woudl wuld 0.34608793
#
# thier thier 2.9802322e-07
# thier their 0.27771842
# thier ur 0.3215202
# thier theirs 0.32483763
# thier own 0.3436761
# thier everyones 0.40623963
# thier alot 0.40639704
# thier our 0.41030878
#
# appartments appartments -3.5762787e-07
# appartments testen 0.40948057
# appartments bedsit 0.4214691
# appartments niceic 0.42864573
# appartments intercom 0.4387939
# appartments rewire 0.45277214
# appartments bungalow 0.45926744
# appartments 2bed 0.46471477
#
# benifits benifits 0.0
# benifits benfits 0.3481186
# benifits benifit 0.46521127
# benifits benefits 0.4652716
# benifits beneﬁts 0.5471126
# benifits perks 0.55383724
# benifits benefi 0.5594711
# benifits benefts 0.56075627
#
# existant existant 0.0
# existant existent 0.2918253
# existant non-existant 0.39078408
# existant nonexistant 0.4290774
# existant non-existent 0.49396878
# existant inexistent 0.5016437
# existant nonexistent 0.50595415
# existant non-existing 0.5732387
#
# saftey saftey -2.3841858e-07
# saftey safty 0.24900192
# saftey safety 0.4810905
# saftey safey 0.49771
# saftey safetly 0.633444
# saftey safeness 0.6410991
# saftey safetysafety 0.64855295
# saftey hygeine 0.6555505

# %% [markdown]
# Replace the nearest misspelled words with their word vectors

# %%
d = { k: [vectors[words.index(w)] for w in v] for k,v in d.items() }

# %% [markdown]
# Create the ensembled tranformation vector

# %%
xform_vecs = []

for k,v in d.items():
    if (not k in words): continue
        
    correct_word = vectors[words.index(k)]
    xform_vecs.append((v - correct_word).mean(axis=0))

# %%
xform_vec = np.array(xform_vecs).mean(axis=0)

# %%
xform_vec.shape
# Out:
# (300,)

# %% [markdown]
# Put the results into a DataFrame for further analysis.
#
# You can use the ensembed vector *or* the one-word vector below, though the former outperforms the later by finding 98% of the misspellings vs. just 87%

# %%
results = []

for w, mw in zip(correct, misspelled):
    if (not w in words): continue
            
    new_vec = vectors[words.index(w)] - xform_vec #one_xform_vec
    knn_idxs, knn_dists = get_knns(nms_idx, np.expand_dims(new_vec, 0))
    nns = [[ words[idx] for idx in idxs ] for idxs in knn_idxs ][0]
    
    results.append({ 
        'incorrect' : mw, 
        'correct' : w, 
        'neighbors' : nns,
        'found' : w in nns, 
        'pos_found' : nns.index(w) if w in nns else -1
    })

# %%
df = pd.DataFrame(results, columns=['incorrect', 'correct', 'neighbors', 'found', 'pos_found'])

# %%
df.head()
# Out:
#     incorrect     correct  \
# 0  acctg       acct
# 1  bailable    available
# 2  abilty      ability
# 3  absolutly   absolutely
# 4  absoultely  absolutely
#
#                                                                        neighbors  \
# 0  [acct, account, accounts, accounting, credit, management, banking, financial]
# 1  [available, only, offered, be, offer, provided, provide, will]
# 2  [ability, able, can, could, certain, allow, cannot, however]
# 3  [absolutely, truly, totally, simply, certainly, really, nothing, sure]
# 4  [absolutely, truly, totally, simply, certainly, really, nothing, sure]
#
#    found  pos_found
# 0  True   0
# 1  True   0
# 2  True   0
# 3  True   0
# 4  True   0

# %%
df_found = df[df.found == True]
df_notfound = df[df.found == False]

print(f'Total: {len(df)} | Found: {len(df_found)} | Not Found: {len(df_notfound)}')
print(f'Found %: {len(df_found) / len(df)}')
# Out:
# Total: 602 | Found: 584 | Not Found: 18
# Found %: 0.9700996677740864
